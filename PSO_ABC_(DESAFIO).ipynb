# %% [markdown]
# <a href="https://colab.research.google.com/github/SanBartolome/IA-diploma-course-2021/blob/main/PSO_ABC_(DESAFIO).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Optimización industrial con Computación Evolutiva
# Dr. Edwin Villanueva Talavera (ervillanueva@pucp.edu.pe)
# Dra. Soledad Espezua Llerena (sespezua@pucp.edu.pe )

# %% [markdown]
# ## DESAFIO: Experimentando con Algoritmos de Inteligencia Colectiva (PSO, ABC)
#
# En este notebook se presenta la implementación de dos algoritmos de Inteligencia Colectiva para minimizar funciones continuas no convexas: el Algoritmo PSO y el Algoritmo ABC.
#
# Al final de este notebook encontrará las preguntas que serán evaluadas

# %% [markdown]
# ### Importa librerias que se van a usar

# %%
#@title Imports - Ejecutar esta celda
import numpy as np
import time
import math
import random as rand
from operator import attrgetter
from copy import deepcopy
import matplotlib.pyplot as plt

np.random.seed(0)

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %% [markdown]
# ## PARTICLE SWARM OPTIMIZATION (PSO)

# %% [markdown]
# ### Define clase Particle
# Un Objeto de esta clase almacena informacion de una particula (solucion candidata) en PSO

# %%
class Particle(object):
    """Clase Particle para almacenar informacion de una particula en PSO """
    
    def __init__(self, initial_position, initial_velocity, fitness): #constructor recibe posicion y velocidad inicial y fitness
        self.position = initial_position
        self.velocity = initial_velocity
        self.fitness = fitness
        self.best_position = initial_position
        self.best_fitness = fitness

# %% [markdown]
# ### Define clase PSO_particles.
# Un Objeto de esta clase almacena información de las partículas creadas para PSO

# %%
class PSO_particles:
    """ Clase que implementa el generador de partículas del optimizador PSO. El constructor puede recibir:
        PN: numero de particulas (Particles Number)
        coord_min: vector con los limites inferiores para delimitar el espacio de busqueda
        coord_max: vector con los limites superiores para delimitar el espacio de busqueda """
    
    def __init__(self, PN, coord_min, coord_max, seed=0):
        self.PN = PN
        self.coord_min = np.array(coord_min)
        self.coord_max = np.array(coord_max)
        self.seed = seed
        self.values = self.initialize_particles()

    def create_particle(self):   # Instancia una particula aleatoria dentro de los limites de busqueda
        position = self.coord_min + rand.random()*(self.coord_max - self.coord_min)
        Vmin = -1*(self.coord_max - self.coord_min)
        Vmax = (self.coord_max - self.coord_min)
        velocity = Vmin + rand.random()*(Vmax - Vmin)
        return [position, velocity]
    
    def initialize_particles(self):  # crea las PN particles de PSO
        return [self.create_particle() for _ in range(self.PN)]

# %% [markdown]
# ### Define clase PSO.
# Un Objeto de esta clase instancia un optimizador PSO para un problema dado

# %%
class PSO:
    """ Clase que implementa el optimizador PSO. El constructor puede recibir:
        fn: La funcion a ser minimizada
        w: factor de inercia de la particula
        phi1: peso de aprendizaje cognitivo
        phi2: peso de aprendizaje social
        max_iter: número total de iteraciones que ejecutará PSO """

    def __init__(self, fn, particles, w, phi1, phi2, max_iter):  
        self.fn = fn
        self.PN = particles.PN
        self.coord_min = particles.coord_min
        self.coord_max = particles.coord_max
        self.w = w
        self.phi1 = phi1
        self.phi2 = phi2
        self.max_iter = max_iter
        self.particles = self.set_particles(particles.values)
        self.best_position_swarm = []
        self.best_fitness_swarm = []
    
    def set_particles(self, particles):
        return [Particle(solution[0], solution[1], self.fitness(solution[0])) for solution in particles]

    def fitness(self, position):  
        # el fitness para fn positivos es trasladado a valores entre [0,1]: 0 para fn=inf y 1 para fn=0. 
        # el fitness para fn negativos es trasladado a valores entre ]1,inf]: 1 para fn=-0 y inf para fn=-inf    
        result = self.fn(position)
        if result >= 0:
            fitness = 1 / (1 + result)
        else:
            fitness = 1 + abs(result)
        return fitness
    
    def get_bestparticle(self):
        best = max(self.particles, key=attrgetter('fitness'))
        return best
        
    def optimize(self):
        start_time = time.time()
        print ('Iniciando optimizacion con Algoritmo PSO')
        
        history_bestfitness = []
        history_bestsolution = []
        best_particle = self.get_bestparticle()
        self.best_position_swarm, self.best_fitness_swarm = deepcopy(best_particle.position), best_particle.fitness 
        history_bestfitness.append(self.best_fitness_swarm)  # almacena la historia de mejores fitness en cada ciclo
        history_bestsolution.append(self.best_position_swarm)
        print("Mejor solucion inicial = {}, fitness = {}".format(self.best_position_swarm, self.best_fitness_swarm))

        for g in range(self.max_iter):  # For each cycle

            for i in range(self.PN): # por cada particula en el swarm

                # si la particula i es mejor que la mejor posicion que ya vió la particula
                if self.particles[i].fitness > self.particles[i].best_fitness: 
                    self.particles[i].best_position = deepcopy(self.particles[i].position)
                    self.particles[i].best_fitness =  self.particles[i].fitness
                
                # si la mejor posicion que ya vió la particula i es mejor que la mejor position de todo el swarm
                if self.particles[i].best_fitness > self.best_fitness_swarm:
                    self.best_position_swarm = deepcopy(self.particles[i].best_position)
                    self.best_fitness_swarm  = self.particles[i].best_fitness
                    
            # Actualiza la velocidad y position de cada particula 1
            for i in range(self.PN): # por cada particula en el swarm
                r1 = rand.random()
                r2 = rand.random()
                self.particles[i].velocity = self.w*self.particles[i].velocity + self.phi1*r1*(self.particles[i].best_position - self.particles[i].position) + self.phi2*r2*(self.best_position_swarm - self.particles[i].position)
                self.particles[i].position = self.particles[i].position + self.particles[i].velocity
                self.particles[i].fitness  = self.fitness(self.particles[i].position)
                

             ## Obtiene la mejor posicion encontrada en este ciclo
            best_particle = self.get_bestparticle()  # mejor posicion del presente ciclo 
            history_bestfitness.append(best_particle.fitness)
            history_bestsolution.append(best_particle.position)
            
            if (g % 5 == 0): # muestra resultados cada 5 ciclos
                print("Ciclo {}, Mejor solucion del ciclo = {} (fitness = {}))".format(g, best_particle.position, best_particle.fitness ))
        
        end_time = time.time()
        print("Mejor solucion encontrada por PSO: {}, fitness = {}. Tomo {} seg ".format(self.best_position_swarm, self.best_fitness_swarm, end_time-start_time))
        return self.best_position_swarm, self.best_fitness_swarm, history_bestfitness, history_bestsolution

# %% [markdown]
# ## ARTIFICIAL BEE COLONY (ABC)

# %% [markdown]
# ### Define clase FoodSource.
# Un Objeto de esta clase almacena informacion de una fuente de comida (solucion candidata) en ABC

# %%
class FoodSource(object):
    """Clase FoodSource para almacenar informacion de una fuente de comida en ABC """
    
    def __init__(self, solution, fitness):  # el constructor recibe una posible solucion (localizacion) y su fitness
        self.solution = solution
        self.fitness = fitness
        self.trials = 0  # esta informacion almacena las veces que la fuente se ha intentado mejorar sin exito

# %% [markdown]
# ### Define clase ABC_foodsources.
# Un Objeto de esta clase almacena información de las fuentes de comida creadas para ABC

# %%
class ABC_foodsources:
    """ Clase que implementa el generador de comida del optimizador ABC. El constructor puede recibir:
        SN: numero de fuentes de comida (Source Number)
        coord_min: vector con los limites inferiores para delimitar el espacio de busqueda
        coord_max: vector con los limites superiores para delimitar el espacio de busqueda """
    
    def __init__(self, SN, coord_min, coord_max, seed=0):
        self.SN = SN
        self.coord_min = np.array(coord_min)
        self.coord_max = np.array(coord_max)
        self.seed = seed
        self.values = self.initialize_foodsources()
    
    def get_randomsolution(self):  # retorna una solucion generada aleatoriamente dentro de los limites coord_min, coord_max
        r = rand.random()
        return self.coord_min + r*(self.coord_max - self.coord_min)
    
    def create_foodsource(self):   # Instancia una fuente de comida aleatoria dentro de los limites de busqueda,
        solution = self.get_randomsolution()
        return solution
    
    def initialize_foodsources(self):  # crea las SN fuentes de comida
        rand.seed(self.seed)
        return [self.create_foodsource() for _ in range(self.SN)]

# %% [markdown]
# ### Define clase ABC.
# Un Objeto de esta clase instancia un optimizador ABC para un problema dado

# %%
class ABC:
    """ Clase que implementa el optimizador ABC. El constructor puede recibir:
        fn: La funcion a ser minimizada
        foodsources: Fuentes de comida
        limit: Número de ciclos que será conservada una solución sin mejorar antes de ser reemplazada
        max_iter: Número total de iteraciones que ejecutará ABC """

    def __init__(self, fn, foodsources, limit, max_iter):
        self.fn = fn
        self.SN = foodsources.SN
        self.coord_min = foodsources.coord_min
        self.coord_max = foodsources.coord_max
        self.limit = limit
        self.max_iter = max_iter
        self.foodsources = self.set_foodsources(foodsources.values)
        self.fn_create_foodsource = foodsources.create_foodsource
    
    def set_foodsources(self, foodsources):
        return [FoodSource(solution, self.fitness(solution)) for solution in foodsources]
    
    def fitness(self, solution):
        # el fitness para fn positivos es trasladado a valores entre [0,1]: 0 para fn=inf y 1 para fn=0.
        # el fitness para fn negativos es trasladado a valores entre ]1,inf]: 1 para fn=-0 y inf para fn=-inf
        
        #return -1*self.fn(solution)
        result = self.fn(solution)
        if result >= 0:
            fitness = 1 / (1 + result)
        else:
            fitness = 1 + abs(result)
        return fitness

    def produce_neighboursolution(self, foodsource_index):  # genera una solucion candidata en la vecindad de la fuente foodsource_index
        Xi = self.foodsources[foodsource_index].solution  # solucion de la fuente pasada
        other_source_indexes = list(range(self.SN))
        del(other_source_indexes[foodsource_index]) # remueve la fuente pasada para no ser seleccionada
        k = rand.choice(other_source_indexes)  # escoje aleatoriamente otra fuente para generar una solucion candidata
        Xk = self.foodsources[k].solution  # solucion de la otra fuente
        r = rand.uniform(-1, 1)
        return  Xi + r * (Xi - Xk)
    
    def get_bestsolution(self, X, V):  # devuelve la solucion con mejor fitness entre la solucion actual X y una solucion candidata V
        if self.fitness(V) > self.fitness(X):
            return V
        else:
            return X

    def get_probs_foodsources(self): # calcula las probabilidades de las fuentes de comida
        fitness_sum = sum([fs.fitness for fs in self.foodsources])
        return [fs.fitness/fitness_sum  for fs in self.foodsources]
    
    def update_solution_foodsource(self, foodsource, new_solution):  # actualiza la solucion de la fuente de comida
        if np.array_equal(new_solution, foodsource.solution): # si es la misma solucion entonces solo aumenta trials de la fuente
            foodsource.trials += 1
        else: # si la nueva solucion es mejor que la actual de la fuente de comida -> actualiza solucion y fitness
            foodsource.solution = new_solution
            foodsource.fitness = self.fitness(new_solution)
            foodsource.trials = 0

    def selection(self, probabilities):  # selecciona una fuente de comida basada en sus probabilidades
        return rand.choices(range(self.SN), probabilities)[0]
    
    def get_bestfoodsource(self):
        best = max(self.foodsources, key=attrgetter('fitness'))
        return best
    
    def create_new_foodsource(self):
        solution = self.fn_create_foodsource()
        return FoodSource(solution, self.fitness(solution))

    def optimize(self):
        start_time = time.time()
        print('Iniciando optimizacion con Algoritmo ABC')
        
        history_bestfitness = []
        history_bestsolution = []
        best_foodsource = self.get_bestfoodsource()
        best_solution, best_fitness = deepcopy(best_foodsource.solution), best_foodsource.fitness
        history_bestfitness.append(best_fitness)  # almacena la historia de mejores fitness en cada ciclo
        history_bestsolution.append(best_solution)
        print("Mejor solucion inicial = {}, fitness = {}".format(best_solution, best_fitness))

        for g in range(self.max_iter):  # For each cycle
            
            ## Etapa de Abejas empleadas (Employed bee)
            for i in range(self.SN): # por cada abeja empleada
                foodsource = self.foodsources[i]
                Vi = self.produce_neighboursolution(i)  # produce una solucion en la vecindad de foodsource
                solution = self.get_bestsolution(foodsource.solution, Vi) # selecciona la mejor solucion entre la actual y la candidata
                self.update_solution_foodsource(foodsource, solution) # actualiza la solucion en la fuente escogida
            
            ## Etapa de Abejas Observadoras (Onlooker bee)
            for i in range(self.SN): # por cada abeja observadora
                probabilities = self.get_probs_foodsources()   # calcula las probabilidades de todas las fuentes de comida
                index_foodsource = self.selection(probabilities) # selecciona una fuente de comida en base a las probabilidades (metodo ruleta)
                foodsource = self.foodsources[index_foodsource]
                Vi = self.produce_neighboursolution(index_foodsource)  # produce una solucion en la vecindad de selected_foodsource
                solution = self.get_bestsolution(foodsource.solution, Vi) # selecciona la mejor solucion entre la fuente seleccionada actual y la candidata
                self.update_solution_foodsource(foodsource, solution)  # actualiza la solucion en la fuente escogida
            
            ## Etapa de Abejas exploradoras (Scout bee)
            for i in range(self.SN): # por cada fuente de comida
                foodsource = self.foodsources[i]
                if foodsource.trials > self.limit:  # si el numero de veces que se intento mejorar la fuente excede el limite entonces abandona
                    self.foodsources[i] = self.create_new_foodsource() # reemplaza la fuente de comida i  por una nueva
            
            ## Memoriza la mejor solucion alcanzada hasta ahora
            best_foodsource = self.get_bestfoodsource()  # mejor fuente del presente ciclo
            history_bestfitness.append ( best_foodsource.fitness )
            history_bestsolution.append(best_foodsource.solution)
            if best_foodsource.fitness >  best_fitness:  # si la mejor solucion del ciclo es mejor que la mejor solucion histórica
                best_solution, best_fitness = deepcopy(best_foodsource.solution), best_foodsource.fitness
            
            if (g % 5 == 0): # muestra resultados cada 5 ciclos
                print("Ciclo {}, Mejor solucion del ciclo = {} (fitness = {}))".format(g, best_foodsource.solution, best_foodsource.fitness))
        
        end_time = time.time()
        print("Mejor solucion encontrada por ABC: {}, fitness = {}. Tomo {} seg ".format(best_solution, best_fitness, end_time-start_time))
        return best_solution, best_fitness, history_bestfitness, history_bestsolution

# %% [markdown]
#  ## Funciones benchmark para evaluar el algoritmo ABC y PSO
#
# Define 3 funciones benchmark para probar el algoritmo ABC para encontrar sus minimos globales. El fitness del optimo global en todos los casos es = 0

# %%
## Funcion  ackley, Typical coord_min = [-20, -20] , coord_max = [20, 20] , optimum at  [0, 0]
def ackley(d, *, a=20, b=0.2, c=2*np.pi):
    sum_part1 = np.sum([x**2 for x in d])
    part1 = -1.0 * a * np.exp(-1.0 * b * np.sqrt((1.0/len(d)) * sum_part1))
    sum_part2 = np.sum([np.cos(c * x) for x in d])
    part2 = -1.0 * np.exp((1.0 / len(d)) * sum_part2)

    return a + np.exp(1) + part1 + part2

## Funcion  rastrigin, Typical coord_min = [-5, -5] , coord_max = [5, 5] , optimum at  [0, 0]
def rastrigin(d):
    sum_i = np.sum([x**2 - 10*np.cos(2 * np.pi * x) for x in d])
    return 10 * len(d) + sum_i

## Funcion  rosenbrock,  Typical  coord_min = [-3, -3] , coord_max = [3, 3] , optimum at  [0, 0]
def rosenbrock(d, a=1, b=100):
    return (a - d[0])**2 + b * (d[1] - d[0]**2)**2

## Funcion  schwefel, Typical coord_min = [-500, -500] , coord_max = [500, 500] , optimum at [420.968, 420.968]
def schwefel(x):
    val = 0
    d = len(x)
    for i in range(d):
        val += x[i] * math.sin(math.sqrt(abs(x[i])))
    val = 418.9829 * d - val
    return val

# %% [markdown]
#  ## Probando el algoritmo PSO
#
#  los parametros que se pasan a PSO son (fn, PN, Xmin, Xmax, w, phi1, phi2, max_iter):
#
#         fn: La funcion a ser minimizada
#         PN: numero de particulas
#         Xmin: vector con los limites inferiores para delimitar el espacio de busqueda
#         Xmax: vector con los limites superiores para delimitar el espacio de busqueda
#         w: factor de inercia de la particula
#         phi1: peso de aprendizaje cognitivo
#         phi2: peso de aprendizaje social
#         max_iter: número total de iteraciones que ejecutará PSO

# %%
# instancia poblacion de particulas para PSO
coord_min = [-20, -20]
coord_max = [20, 20]

initial_particles = PSO_particles(5, coord_min, coord_max)

# %%
# instancia optimizador PSO para minimizar la funcion ackley
pso_optimizer_ackley = PSO(ackley, initial_particles, 0.01, 1, 1, 50)   # w= .01,  phi1=1, phi2=1, iterations=50
best_solution, best_fitness, history_bestfitness, history_bestsolution = pso_optimizer_ackley.optimize()

# muestra la evolucion del mejor fitness
plt.plot(history_bestfitness)
plt.show()

ackley_best_solution = ackley(best_solution)
print("Minimo encontrado con PSO en funcion Ackley: {}, fn={}".format(best_solution, ackley_best_solution))
# Out:
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.61784955 0.61784955], fitness = 0.17969168134258967
# Ciclo 0, Mejor solucion del ciclo = [0.98315037 0.98315037] (fitness = 0.21808883101900464))
# Ciclo 5, Mejor solucion del ciclo = [0.06078082 0.06078082] (fitness = 0.699011735080048))
# Ciclo 10, Mejor solucion del ciclo = [0.04437797 0.04437797] (fitness = 0.7814247626049063))
# Ciclo 15, Mejor solucion del ciclo = [0.04301755 0.04301755] (fitness = 0.7884872149677666))
# Ciclo 20, Mejor solucion del ciclo = [0.04301754 0.04301754] (fitness = 0.7884872563949457))
# Ciclo 25, Mejor solucion del ciclo = [0.04301697 0.04301697] (fitness = 0.78849024146017))
# Ciclo 30, Mejor solucion del ciclo = [0.04301697 0.04301697] (fitness = 0.7884902414604315))
# Ciclo 35, Mejor solucion del ciclo = [0.04301697 0.04301697] (fitness = 0.7884902414638327))
# Ciclo 40, Mejor solucion del ciclo = [0.04301697 0.04301697] (fitness = 0.7884902414638656))
# Ciclo 45, Mejor solucion del ciclo = [0.04301697 0.04301697] (fitness = 0.7884902414638684))
# Mejor solucion encontrada por PSO: [0.04301697 0.04301697], fitness = 0.7884902414638684. Tomo 0.021178007125854492 seg
# Minimo encontrado con PSO en funcion Ackley: [0.04301697 0.04301697], fn=0.2682465139244514

# %% [markdown]
#  ## Probando el algoritmo ABC
#
#  los parametros que se pasan a ABC son (fn, SN, Xmin, Xmax, limit, max_iter):
#
#         fn: La funcion a ser minimizada
#         SN: numero de fuentes de comida (Source Number)
#         Xmin: vector con los limites inferiores para delimitar el espacio de busqueda
#         Xmax: vector con los limites superiores para delimitar el espacio de busqueda
#         limit: numero de ciclos que será conservada una solución sin mejorar antes de ser reemplazada
#         max_iter: número total de iteraciones que ejecutará ABC

# %%
# instancia fuentes de comida para ABC
coord_min = [-20, -20]
coord_max = [20, 20]

initial_foodsources = ABC_foodsources(5, coord_min, coord_max)

# %%
# instancia optimizador ABC para minimizar la funcion ackley
abc_optimizer_ackley = ABC(ackley, initial_foodsources, 25, 50)  #limit=25, iterations=50
best_solution, best_fitness, history_bestfitness, history_bestsolution = abc_optimizer_ackley.optimize()

# muestra la evolucion del mejor fitness
plt.plot(history_bestfitness)
plt.show()

ackley_best_solution = ackley(best_solution)
print("Minimo encontrado con ABC en funcion Ackley: {}, fn={}".format(best_solution, ackley_best_solution))
# Out:
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.30892802 0.30892802] (fitness = 0.2369550697304413))
# Ciclo 5, Mejor solucion del ciclo = [-0.02325347 -0.02325347] (fitness = 0.8915786159695762))
# Ciclo 10, Mejor solucion del ciclo = [-0.00318828 -0.00318828] (fitness = 0.9868800291092786))
# Ciclo 15, Mejor solucion del ciclo = [-0.00028052 -0.00028052] (fitness = 0.9988750035409698))
# Ciclo 20, Mejor solucion del ciclo = [-0.00015992 -0.00015992] (fitness = 0.9993593847316958))
# Ciclo 25, Mejor solucion del ciclo = [-0.0001528 -0.0001528] (fitness = 0.9993879157869687))
# Ciclo 30, Mejor solucion del ciclo = [-0.00015137 -0.00015137] (fitness = 0.9993936776965017))
# Ciclo 35, Mejor solucion del ciclo = [-0.00014578 -0.00014578] (fitness = 0.9994160933760009))
# Ciclo 40, Mejor solucion del ciclo = [-0.00011138 -0.00011138] (fitness = 0.9995540109096087))
# Ciclo 45, Mejor solucion del ciclo = [1.34145774e-05 1.34145774e-05] (fitness = 0.9999463349867939))
# Mejor solucion encontrada por ABC: [-2.34346804e-08 -2.34346804e-08], fitness = 0.99999990626126. Tomo 0.05762529373168945 seg
# Minimo encontrado con ABC en funcion Ackley: [-2.34346804e-08 -2.34346804e-08], fn=9.373874876317245e-08

# %% [markdown]
# # Tareas y cuestiones:

# %% [markdown]
# <b>1) Ejecutar 10 veces ABC en funcion ACkley para cada valor indicado del parametro limit y los sgtes parametros</b>
#
#       - SN = 5
#       - limit = {1,10,50 }
#       - max_iter = 50
#       - coord_min = [-20, -20]
#       - coord_max = [20, 20]
#
#   Registre la media y desviación estandard del fitness de la mejor solución encontrada para cada valor del parametro limit
#
#   En base a los resultados obtenidos comente que efecto tiene el parámetro limit en la capacidad de ABC de encontrar optimos. Relacione con qué rol está asociado dicho parámetro (exploracion o explotacion?)

# %%
# instancia fuentes de comida para ABC
sn = 5
max_iter = 50
coord_min = [-20, -20]
coord_max = [20, 20]

initial_foodsources = ABC_foodsources(sn, coord_min, coord_max)

# %%
limit = {1, 10, 50}
total_abc = []
j = 0
for lim in limit:
  total_abc.append([])
  for i in range(10):
    # instancia optimizador ABC para minimizar la funcion ackley
    abc_optimizer_ackley = ABC(ackley, initial_foodsources, lim, max_iter)
    best_solution, best_fitness, history_bestfitness, history_bestsolution = abc_optimizer_ackley.optimize()
    # ackley_best_solution = ackley(best_solution)
    total_abc[j].append(best_fitness)
  j = j + 1
# Out:
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.30892802 0.30892802] (fitness = 0.2369550697304413))
# Ciclo 5, Mejor solucion del ciclo = [-1.68183185 -1.68183185] (fitness = 0.1140129012947844))
# Ciclo 10, Mejor solucion del ciclo = [-8.94012327 -8.94012327] (fitness = 0.056060689786087955))
# Ciclo 15, Mejor solucion del ciclo = [-2.83757684 -2.83757684] (fitness = 0.09352169658673079))
# Ciclo 20, Mejor solucion del ciclo = [1.39189507 1.39189507] (fitness = 0.1231711660101713))
# Ciclo 25, Mejor solucion del ciclo = [-1.12750744 -1.12750744] (fitness = 0.1738981387870994))
# Ciclo 30, Mejor solucion del ciclo = [-2.00761517 -2.00761517] (fitness = 0.13128336667077375))
# Ciclo 35, Mejor solucion del ciclo = [0.74830832 0.74830832] (fitness = 0.18152543775374155))
# Ciclo 40, Mejor solucion del ciclo = [-4.5349987 -4.5349987] (fitness = 0.06550177656028842))
# Ciclo 45, Mejor solucion del ciclo = [-5.91671311 -5.91671311] (fitness = 0.06572277546850583))
# Mejor solucion encontrada por ABC: [0.04147125 0.04147125], fitness = 0.7965406183816122. Tomo 0.07239651679992676 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [-2.94000231 -2.94000231] (fitness = 0.09924977372597187))
# Ciclo 5, Mejor solucion del ciclo = [-0.99839065 -0.99839065] (fitness = 0.21643838426474257))
# Ciclo 10, Mejor solucion del ciclo = [1.30196241 1.30196241] (fitness = 0.13196660067494612))
# Ciclo 15, Mejor solucion del ciclo = [-2.22505933 -2.22505933] (fitness = 0.10274277215522891))
# Ciclo 20, Mejor solucion del ciclo = [0.22117298 0.22117298] (fitness = 0.29530660155302463))
# Ciclo 25, Mejor solucion del ciclo = [3.67086753 3.67086753] (fitness = 0.07407636763323222))
# Ciclo 30, Mejor solucion del ciclo = [2.39014966 2.39014966] (fitness = 0.0921174144013584))
# Ciclo 35, Mejor solucion del ciclo = [-1.23392002 -1.23392002] (fitness = 0.1431440553194503))
# Ciclo 40, Mejor solucion del ciclo = [0.19024437 0.19024437] (fitness = 0.33090624366047294))
# Ciclo 45, Mejor solucion del ciclo = [0.86924528 0.86924528] (fitness = 0.20268389590085764))
# Mejor solucion encontrada por ABC: [-0.00401854 -0.00401854], fitness = 0.9833480025964174. Tomo 0.06736588478088379 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.9745348 0.9745348] (fitness = 0.2185182987846291))
# Ciclo 5, Mejor solucion del ciclo = [0.21416597 0.21416597] (fitness = 0.3024145175274597))
# Ciclo 10, Mejor solucion del ciclo = [5.71749471 5.71749471] (fitness = 0.0605040561539456))
# Ciclo 15, Mejor solucion del ciclo = [-0.8421196 -0.8421196] (fitness = 0.19645326805801605))
# Ciclo 20, Mejor solucion del ciclo = [0.06320932 0.06320932] (fitness = 0.6873800793611843))
# Ciclo 25, Mejor solucion del ciclo = [-2.01214695 -2.01214695] (fitness = 0.13099240236045193))
# Ciclo 30, Mejor solucion del ciclo = [-1.69103631 -1.69103631] (fitness = 0.11414100395190703))
# Ciclo 35, Mejor solucion del ciclo = [3.88925579 3.88925579] (fitness = 0.08080146148163089))
# Ciclo 40, Mejor solucion del ciclo = [-0.01883401 -0.01883401] (fitness = 0.913960728366233))
# Ciclo 45, Mejor solucion del ciclo = [-1.20308507 -1.20308507] (fitness = 0.15018849024202421))
# Mejor solucion encontrada por ABC: [0.00081085 0.00081085], fitness = 0.9967323001970941. Tomo 0.07324790954589844 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [-2.05221045 -2.05221045] (fitness = 0.1269999021619361))
# Ciclo 5, Mejor solucion del ciclo = [-0.84030325 -0.84030325] (fitness = 0.19605458519729174))
# Ciclo 10, Mejor solucion del ciclo = [0.24951444 0.24951444] (fitness = 0.2710915895668474))
# Ciclo 15, Mejor solucion del ciclo = [1.66341613 1.66341613] (fitness = 0.11386439936246583))
# Ciclo 20, Mejor solucion del ciclo = [5.91204124 5.91204124] (fitness = 0.0655944340806962))
# Ciclo 25, Mejor solucion del ciclo = [0.09351624 0.09351624] (fitness = 0.5585637061371855))
# Ciclo 30, Mejor solucion del ciclo = [-2.05947087 -2.05947087] (fitness = 0.12604997094782774))
# Ciclo 35, Mejor solucion del ciclo = [1.0999712 1.0999712] (fitness = 0.18443803146166637))
# Ciclo 40, Mejor solucion del ciclo = [-0.94621591 -0.94621591] (fitness = 0.21749668043906814))
# Ciclo 45, Mejor solucion del ciclo = [0.3010673 0.3010673] (fitness = 0.240528850773358))
# Mejor solucion encontrada por ABC: [-0.00419639 -0.00419639], fitness = 0.9825854776587538. Tomo 0.06282305717468262 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [-1.02214306 -1.02214306] (fitness = 0.21169033499661521))
# Ciclo 5, Mejor solucion del ciclo = [-0.01108417 -0.01108417] (fitness = 0.9515932912153765))
# Ciclo 10, Mejor solucion del ciclo = [-0.71175651 -0.71175651] (fitness = 0.1790915222282268))
# Ciclo 15, Mejor solucion del ciclo = [-2.07695205 -2.07695205] (fitness = 0.12356743985106299))
# Ciclo 20, Mejor solucion del ciclo = [2.35989017 2.35989017] (fitness = 0.09333578909913609))
# Ciclo 25, Mejor solucion del ciclo = [0.38045922 0.38045922] (fitness = 0.21266622126591753))
# Ciclo 30, Mejor solucion del ciclo = [1.20644065 1.20644065] (fitness = 0.14935100531294945))
# Ciclo 35, Mejor solucion del ciclo = [-0.83721295 -0.83721295] (fitness = 0.19538365720965148))
# Ciclo 40, Mejor solucion del ciclo = [2.01804288 2.01804288] (fitness = 0.1305605227698525))
# Ciclo 45, Mejor solucion del ciclo = [0.99229101 0.99229101] (fitness = 0.21723520819665965))
# Mejor solucion encontrada por ABC: [-0.01108417 -0.01108417], fitness = 0.9515932912153765. Tomo 0.05785799026489258 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [-0.39697916 -0.39697916] (fitness = 0.20857490922386623))
# Ciclo 5, Mejor solucion del ciclo = [-2.20578922 -2.20578922] (fitness = 0.10485536001839842))
# Ciclo 10, Mejor solucion del ciclo = [-0.8505645 -0.8505645] (fitness = 0.19834472749842183))
# Ciclo 15, Mejor solucion del ciclo = [-0.2801338 -0.2801338] (fitness = 0.25128393302951607))
# Ciclo 20, Mejor solucion del ciclo = [0.1708556 0.1708556] (fitness = 0.35985872418703885))
# Ciclo 25, Mejor solucion del ciclo = [-2.05987092 -2.05987092] (fitness = 0.12599606657163007))
# Ciclo 30, Mejor solucion del ciclo = [-0.6378687 -0.6378687] (fitness = 0.1788762888415112))
# Ciclo 35, Mejor solucion del ciclo = [-0.73853966 -0.73853966] (fitness = 0.1806998417192791))
# Ciclo 40, Mejor solucion del ciclo = [4.10776742 4.10776742] (fitness = 0.07847319574828282))
# Ciclo 45, Mejor solucion del ciclo = [0.77483514 0.77483514] (fitness = 0.18445844539670092))
# Mejor solucion encontrada por ABC: [-0.06206265 -0.06206265], fitness = 0.692850758055669. Tomo 0.06914544105529785 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [-0.23970612 -0.23970612] (fitness = 0.27872871176803443))
# Ciclo 5, Mejor solucion del ciclo = [0.60948706 0.60948706] (fitness = 0.18012595959129157))
# Ciclo 10, Mejor solucion del ciclo = [2.16284587 2.16284587] (fitness = 0.11039513096632757))
# Ciclo 15, Mejor solucion del ciclo = [-0.15176862 -0.15176862] (fitness = 0.3948804176347036))
# Ciclo 20, Mejor solucion del ciclo = [0.10700471 0.10700471] (fitness = 0.5114829160835295))
# Ciclo 25, Mejor solucion del ciclo = [-0.26085177 -0.26085177] (fitness = 0.2631024733861803))
# Ciclo 30, Mejor solucion del ciclo = [1.09515761 1.09515761] (fitness = 0.18632404139975417))
# Ciclo 35, Mejor solucion del ciclo = [1.63005915 1.63005915] (fitness = 0.11392254735520813))
# Ciclo 40, Mejor solucion del ciclo = [-1.46162668 -1.46162668] (fitness = 0.118918884443296))
# Ciclo 45, Mejor solucion del ciclo = [0.85895911 0.85895911] (fitness = 0.20027540358976728))
# Mejor solucion encontrada por ABC: [0.02554847 0.02554847], fitness = 0.8797725291227358. Tomo 0.0644221305847168 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [-3.17713677 -3.17713677] (fitness = 0.08644309404816186))
# Ciclo 5, Mejor solucion del ciclo = [-0.53334412 -0.53334412] (fitness = 0.1863653707043057))
# Ciclo 10, Mejor solucion del ciclo = [3.4857568 3.4857568] (fitness = 0.07468879613170719))
# Ciclo 15, Mejor solucion del ciclo = [-4.88964953 -4.88964953] (fitness = 0.07123184366372227))
# Ciclo 20, Mejor solucion del ciclo = [0.08884814 0.08884814] (fitness = 0.5763243336397621))
# Ciclo 25, Mejor solucion del ciclo = [2.13589857 2.13589857] (fitness = 0.11438727592799575))
# Ciclo 30, Mejor solucion del ciclo = [1.15700976 1.15700976] (fitness = 0.16356298081580606))
# Ciclo 35, Mejor solucion del ciclo = [-2.28102375 -2.28102375] (fitness = 0.09784073439134651))
# Ciclo 40, Mejor solucion del ciclo = [0.86708234 0.86708234] (fitness = 0.20217515179145767))
# Ciclo 45, Mejor solucion del ciclo = [-1.26585992 -1.26585992] (fitness = 0.1372440167187838))
# Mejor solucion encontrada por ABC: [0.02033556 0.02033556], fitness = 0.9064163745167234. Tomo 0.06805682182312012 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.45098885 0.45098885] (fitness = 0.19771934460324359))
# Ciclo 5, Mejor solucion del ciclo = [-3.00752021 -3.00752021] (fitness = 0.09956890852332032))
# Ciclo 10, Mejor solucion del ciclo = [0.37272571 0.37272571] (fitness = 0.2147370412150947))
# Ciclo 15, Mejor solucion del ciclo = [0.51716671 0.51716671] (fitness = 0.18819860488561388))
# Ciclo 20, Mejor solucion del ciclo = [1.22564444 1.22564444] (fitness = 0.14489513182405567))
# Ciclo 25, Mejor solucion del ciclo = [1.12756711 1.12756711] (fitness = 0.17387605127077962))
# Ciclo 30, Mejor solucion del ciclo = [0.50159151 0.50159151] (fitness = 0.1901359391825722))
# Ciclo 35, Mejor solucion del ciclo = [-1.33060186 -1.33060186] (fitness = 0.12860600646761897))
# Ciclo 40, Mejor solucion del ciclo = [-1.19398714 -1.19398714] (fitness = 0.15255062810174036))
# Ciclo 45, Mejor solucion del ciclo = [-0.44852551 -0.44852551] (fitness = 0.19814492925846364))
# Mejor solucion encontrada por ABC: [0.03742656 0.03742656], fitness = 0.8177009401522887. Tomo 0.0854949951171875 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [1.45741604 1.45741604] (fitness = 0.11913291743162607))
# Ciclo 5, Mejor solucion del ciclo = [-2.12494672 -2.12494672] (fitness = 0.11608804014938484))
# Ciclo 10, Mejor solucion del ciclo = [-0.77075775 -0.77075775] (fitness = 0.18394024386346322))
# Ciclo 15, Mejor solucion del ciclo = [-1.07831254 -1.07831254] (fitness = 0.19290335434074127))
# Ciclo 20, Mejor solucion del ciclo = [-0.09827667 -0.09827667] (fitness = 0.5412368203551682))
# Ciclo 25, Mejor solucion del ciclo = [2.50004627 2.50004627] (fitness = 0.08912734264657445))
# Ciclo 30, Mejor solucion del ciclo = [-2.17554715 -2.17554715] (fitness = 0.10864083660955628))
# Ciclo 35, Mejor solucion del ciclo = [0.39870147 0.39870147] (fitness = 0.208172378146995))
# Ciclo 40, Mejor solucion del ciclo = [-0.77333829 -0.77333829] (fitness = 0.18426532742798654))
# Ciclo 45, Mejor solucion del ciclo = [3.14536731 3.14536731] (fitness = 0.08917306670559698))
# Mejor solucion encontrada por ABC: [-0.02549845 -0.02549845], fitness = 0.8800309315945647. Tomo 0.06756711006164551 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.45098885 0.45098885] (fitness = 0.19771934460324359))
# Ciclo 5, Mejor solucion del ciclo = [0.99662092 0.99662092] (fitness = 0.21668812621182731))
# Ciclo 10, Mejor solucion del ciclo = [0.03627247 0.03627247] (fitness = 0.8237540454775129))
# Ciclo 15, Mejor solucion del ciclo = [0.00110139 0.00110139] (fitness = 0.9955497202634043))
# Ciclo 20, Mejor solucion del ciclo = [-4.91249365e-05 -4.91249365e-05] (fitness = 0.9998034103867567))
# Ciclo 25, Mejor solucion del ciclo = [0.00108228 0.00108228] (fitness = 0.9956276842855404))
# Ciclo 30, Mejor solucion del ciclo = [0.00066041 0.00066041] (fitness = 0.9973422131994342))
# Ciclo 35, Mejor solucion del ciclo = [-6.8339133e-05 -6.8339133e-05] (fitness = 0.9997264695859429))
# Ciclo 40, Mejor solucion del ciclo = [6.87240258e-09 6.87240258e-09] (fitness = 0.9999999725103866))
# Ciclo 45, Mejor solucion del ciclo = [6.87240258e-09 6.87240258e-09] (fitness = 0.9999999725103866))
# Mejor solucion encontrada por ABC: [-1.98145157e-10 -1.98145157e-10], fitness = 0.9999999992074184. Tomo 0.05036759376525879 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.32267118 0.32267118] (fitness = 0.23122737246597128))
# Ciclo 5, Mejor solucion del ciclo = [0.21822022 0.21822022] (fitness = 0.29824083838039633))
# Ciclo 10, Mejor solucion del ciclo = [-0.00045597 -0.00045597] (fitness = 0.9981684233301537))
# Ciclo 15, Mejor solucion del ciclo = [3.71671512e-05 3.71671512e-05] (fitness = 0.9998512799476266))
# Ciclo 20, Mejor solucion del ciclo = [-0.00010719 -0.00010719] (fitness = 0.9995708199603116))
# Ciclo 25, Mejor solucion del ciclo = [-1.17044731e-06 -1.17044731e-06] (fitness = 0.9999953181597178))
# Ciclo 30, Mejor solucion del ciclo = [-1.46497438e-06 -1.46497438e-06] (fitness = 0.9999941400225313))
# Ciclo 35, Mejor solucion del ciclo = [-4.08121099e-07 -4.08121099e-07] (fitness = 0.9999983675094013))
# Ciclo 40, Mejor solucion del ciclo = [3.54724368e-06 3.54724368e-06] (fitness = 0.9999858105564983))
# Ciclo 45, Mejor solucion del ciclo = [-2.58635417e-09 -2.58635417e-09] (fitness = 0.9999999896545836))
# Mejor solucion encontrada por ABC: [-2.58635417e-09 -2.58635417e-09], fitness = 0.9999999896545836. Tomo 0.058130502700805664 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.45098885 0.45098885] (fitness = 0.19771934460324359))
# Ciclo 5, Mejor solucion del ciclo = [-0.03220473 -0.03220473] (fitness = 0.8450919541818382))
# Ciclo 10, Mejor solucion del ciclo = [-0.00450842 -0.00450842] (fitness = 0.9812426884700806))
# Ciclo 15, Mejor solucion del ciclo = [8.69591358e-05 8.69591358e-05] (fitness = 0.999651881963477))
# Ciclo 20, Mejor solucion del ciclo = [1.85719722e-05 1.85719722e-05] (fitness = 0.9999256992628424))
# Ciclo 25, Mejor solucion del ciclo = [-2.55524666e-07 -2.55524666e-07] (fitness = 0.9999989778989049))
# Ciclo 30, Mejor solucion del ciclo = [5.63771613e-09 5.63771613e-09] (fitness = 0.9999999774491349))
# Ciclo 35, Mejor solucion del ciclo = [-8.38454164e-11 -8.38454164e-11] (fitness = 0.9999999996646207))
# Ciclo 40, Mejor solucion del ciclo = [3.41430202e-11 3.41430202e-11] (fitness = 0.999999999863427))
# Ciclo 45, Mejor solucion del ciclo = [1.58068499e-10 1.58068499e-10] (fitness = 0.9999999993677275))
# Mejor solucion encontrada por ABC: [1.17335678e-11 1.17335678e-11], fitness = 0.9999999999530655. Tomo 0.0541684627532959 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.45098885 0.45098885] (fitness = 0.19771934460324359))
# Ciclo 5, Mejor solucion del ciclo = [-0.00123363 -0.00123363] (fitness = 0.995009473640981))
# Ciclo 10, Mejor solucion del ciclo = [0.00784695 0.00784695] (fitness = 0.9664969563065982))
# Ciclo 15, Mejor solucion del ciclo = [-0.07579914 -0.07579914] (fitness = 0.6300453215905986))
# Ciclo 20, Mejor solucion del ciclo = [-0.00017226 -0.00017226] (fitness = 0.999309849663776))
# Ciclo 25, Mejor solucion del ciclo = [-5.56833032e-05 -5.56833032e-05] (fitness = 0.9997771513303083))
# Ciclo 30, Mejor solucion del ciclo = [-9.4877516e-06 -9.4877516e-06] (fitness = 0.9999620456401419))
# Ciclo 35, Mejor solucion del ciclo = [8.7200763e-08 8.7200763e-08] (fitness = 0.9999996511966658))
# Ciclo 40, Mejor solucion del ciclo = [8.90687955e-09 8.90687955e-09] (fitness = 0.999999964372479))
# Ciclo 45, Mejor solucion del ciclo = [2.27004782e-09 2.27004782e-09] (fitness = 0.999999990919808))
# Mejor solucion encontrada por ABC: [2.13952965e-09 2.13952965e-09], fitness = 0.9999999914418828. Tomo 0.054900407791137695 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.45098885 0.45098885] (fitness = 0.19771934460324359))
# Ciclo 5, Mejor solucion del ciclo = [0.00159446 0.00159446] (fitness = 0.9935289262386966))
# Ciclo 10, Mejor solucion del ciclo = [0.00067152 0.00067152] (fitness = 0.997297218439847))
# Ciclo 15, Mejor solucion del ciclo = [-6.0865652e-05 -6.0865652e-05] (fitness = 0.9997563994515196))
# Ciclo 20, Mejor solucion del ciclo = [-0.01537781 -0.01537781] (fitness = 0.9310415126723295))
# Ciclo 25, Mejor solucion del ciclo = [-0.00253775 -0.00253775] (fitness = 0.9896150307977606))
# Ciclo 30, Mejor solucion del ciclo = [-2.16799098e-05 -2.16799098e-05] (fitness = 0.999913262852948))
# Ciclo 35, Mejor solucion del ciclo = [-0.0005371 -0.0005371] (fitness = 0.9978409092782995))
# Ciclo 40, Mejor solucion del ciclo = [-0.00039661 -0.00039661] (fitness = 0.9984077142399497))
# Ciclo 45, Mejor solucion del ciclo = [-0.00032252 -0.00032252] (fitness = 0.9987060721379877))
# Mejor solucion encontrada por ABC: [1.97623029e-05 1.97623029e-05], fitness = 0.9999209362404671. Tomo 0.05783700942993164 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [-0.144568 -0.144568] (fitness = 0.4100838637444717))
# Ciclo 5, Mejor solucion del ciclo = [0.08425024 0.08425024] (fitness = 0.5945694517021435))
# Ciclo 10, Mejor solucion del ciclo = [0.03482164 0.03482164] (fitness = 0.8313668178429113))
# Ciclo 15, Mejor solucion del ciclo = [0.01498932 0.01498932] (fitness = 0.9329337175522564))
# Ciclo 20, Mejor solucion del ciclo = [0.00135458 0.00135458] (fitness = 0.9945142268192562))
# Ciclo 25, Mejor solucion del ciclo = [-1.24694091e-05 -1.24694091e-05] (fitness = 0.9999501165714739))
# Ciclo 30, Mejor solucion del ciclo = [-6.30151507e-06 -6.30151507e-06] (fitness = 0.9999747924603851))
# Ciclo 35, Mejor solucion del ciclo = [-5.92054938e-07 -5.92054938e-07] (fitness = 0.9999976317671894))
# Ciclo 40, Mejor solucion del ciclo = [7.70162776e-08 7.70162776e-08] (fitness = 0.9999996919346693))
# Ciclo 45, Mejor solucion del ciclo = [-1.93827409e-09 -1.93827409e-09] (fitness = 0.9999999922469064))
# Mejor solucion encontrada por ABC: [-3.44684798e-11 -3.44684798e-11], fitness = 0.9999999998621267. Tomo 0.061231136322021484 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.45098885 0.45098885] (fitness = 0.19771934460324359))
# Ciclo 5, Mejor solucion del ciclo = [-0.00374731 -0.00374731] (fitness = 0.9845068693235209))
# Ciclo 10, Mejor solucion del ciclo = [0.00012957 0.00012957] (fitness = 0.999481089638865))
# Ciclo 15, Mejor solucion del ciclo = [4.45198342e-05 4.45198342e-05] (fitness = 0.9998218468519016))
# Ciclo 20, Mejor solucion del ciclo = [0.00021908 0.00021908] (fitness = 0.999121910973634))
# Ciclo 25, Mejor solucion del ciclo = [4.7003771e-05 4.7003771e-05] (fitness = 0.9998119026403891))
# Ciclo 30, Mejor solucion del ciclo = [9.48891795e-06 9.48891795e-06] (fitness = 0.9999620409739455))
# Ciclo 35, Mejor solucion del ciclo = [-0.00041811 -0.00041811] (fitness = 0.9983210913265411))
# Ciclo 40, Mejor solucion del ciclo = [-0.87062972 -0.87062972] (fitness = 0.20300982372158163))
# Ciclo 45, Mejor solucion del ciclo = [0.03537399 0.03537399] (fitness = 0.8284684069113196))
# Mejor solucion encontrada por ABC: [9.48891795e-06 9.48891795e-06], fitness = 0.9999620409739455. Tomo 0.06294512748718262 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [-0.13007421 -0.13007421] (fitness = 0.44450969970429416))
# Ciclo 5, Mejor solucion del ciclo = [0.00016184 0.00016184] (fitness = 0.9993516479329738))
# Ciclo 10, Mejor solucion del ciclo = [0.00017525 0.00017525] (fitness = 0.999297849935909))
# Ciclo 15, Mejor solucion del ciclo = [0.0046964 0.0046964] (fitness = 0.9804306945631253))
# Ciclo 20, Mejor solucion del ciclo = [0.02471708 0.02471708] (fitness = 0.884061403696254))
# Ciclo 25, Mejor solucion del ciclo = [0.00058037 0.00058037] (fitness = 0.9976660298210187))
# Ciclo 30, Mejor solucion del ciclo = [0.00430341 0.00430341] (fitness = 0.9821256094421377))
# Ciclo 35, Mejor solucion del ciclo = [0.00304809 0.00304809] (fitness = 0.987471854450729))
# Ciclo 40, Mejor solucion del ciclo = [0.00817022 0.00817022] (fitness = 0.9650341476251341))
# Ciclo 45, Mejor solucion del ciclo = [-0.00091081 -0.00091081] (fitness = 0.9963261312584807))
# Mejor solucion encontrada por ABC: [0.00016184 0.00016184], fitness = 0.9993516479329738. Tomo 0.06055736541748047 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.45098885 0.45098885] (fitness = 0.19771934460324359))
# Ciclo 5, Mejor solucion del ciclo = [-0.01968537 -0.01968537] (fitness = 0.9096914786357883))
# Ciclo 10, Mejor solucion del ciclo = [0.00422189 0.00422189] (fitness = 0.9824759475433705))
# Ciclo 15, Mejor solucion del ciclo = [0.00060817 0.00060817] (fitness = 0.9975536097281575))
# Ciclo 20, Mejor solucion del ciclo = [0.00020365 0.00020365] (fitness = 0.9991838418968189))
# Ciclo 25, Mejor solucion del ciclo = [-1.27646659e-06 -1.27646659e-06] (fitness = 0.9999948940729272))
# Ciclo 30, Mejor solucion del ciclo = [9.50294305e-10 9.50294305e-10] (fitness = 0.9999999961988242))
# Ciclo 35, Mejor solucion del ciclo = [-3.59857184e-10 -3.59857184e-10] (fitness = 0.9999999985605723))
# Ciclo 40, Mejor solucion del ciclo = [-1.5470599e-12 -1.5470599e-12] (fitness = 0.9999999999938116))
# Ciclo 45, Mejor solucion del ciclo = [7.83827648e-13 7.83827648e-13] (fitness = 0.999999999996867))
# Mejor solucion encontrada por ABC: [7.72598779e-15 7.72598779e-15], fitness = 0.9999999999999685. Tomo 0.0705258846282959 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.99541681 0.99541681] (fitness = 0.21684940531779434))
# Ciclo 5, Mejor solucion del ciclo = [0.06157432 0.06157432] (fitness = 0.6951922753206857))
# Ciclo 10, Mejor solucion del ciclo = [-0.00603108 -0.00603108] (fitness = 0.9746013373820501))
# Ciclo 15, Mejor solucion del ciclo = [0.00048915 0.00048915] (fitness = 0.9980345463598546))
# Ciclo 20, Mejor solucion del ciclo = [-4.15503177e-05 -4.15503177e-05] (fitness = 0.9998337344340016))
# Ciclo 25, Mejor solucion del ciclo = [-9.78960716e-07 -9.78960716e-07] (fitness = 0.9999960841214317))
# Ciclo 30, Mejor solucion del ciclo = [-9.78960716e-07 -9.78960716e-07] (fitness = 0.9999960841214317))
# Ciclo 35, Mejor solucion del ciclo = [-2.08658466e-08 -2.08658466e-08] (fitness = 0.999999916536597))
# Ciclo 40, Mejor solucion del ciclo = [-1.2491308e-11 -1.2491308e-11] (fitness = 0.9999999999500351))
# Ciclo 45, Mejor solucion del ciclo = [-1.2491308e-11 -1.2491308e-11] (fitness = 0.9999999999500351))
# Mejor solucion encontrada por ABC: [-2.43683934e-13 -2.43683934e-13], fitness = 0.999999999999027. Tomo 0.05252790451049805 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.45098885 0.45098885] (fitness = 0.19771934460324359))
# Ciclo 5, Mejor solucion del ciclo = [0.04717694 0.04717694] (fitness = 0.7669756574454136))
# Ciclo 10, Mejor solucion del ciclo = [-0.00025773 -0.00025773] (fitness = 0.9989665956352011))
# Ciclo 15, Mejor solucion del ciclo = [5.55717155e-05 5.55717155e-05] (fitness = 0.9997775981435084))
# Ciclo 20, Mejor solucion del ciclo = [5.13182023e-06 5.13182023e-06] (fitness = 0.9999794717379438))
# Ciclo 25, Mejor solucion del ciclo = [-2.90179049e-07 -2.90179049e-07] (fitness = 0.9999988392806664))
# Ciclo 30, Mejor solucion del ciclo = [1.12080403e-08 1.12080403e-08] (fitness = 0.9999999551678365))
# Ciclo 35, Mejor solucion del ciclo = [5.10898609e-09 5.10898609e-09] (fitness = 0.9999999795640551))
# Ciclo 40, Mejor solucion del ciclo = [-3.95455857e-10 -3.95455857e-10] (fitness = 0.999999998418176))
# Ciclo 45, Mejor solucion del ciclo = [4.34380922e-12 4.34380922e-12] (fitness = 0.9999999999826241))
# Mejor solucion encontrada por ABC: [-6.14307603e-14 -6.14307603e-14], fitness = 0.9999999999997553. Tomo 0.05341506004333496 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.45098885 0.45098885] (fitness = 0.19771934460324359))
# Ciclo 5, Mejor solucion del ciclo = [0.02738934 0.02738934] (fitness = 0.8702345574903986))
# Ciclo 10, Mejor solucion del ciclo = [0.02532947 0.02532947] (fitness = 0.8809034889541653))
# Ciclo 15, Mejor solucion del ciclo = [-0.00516728 -0.00516728] (fitness = 0.9783868151907751))
# Ciclo 20, Mejor solucion del ciclo = [0.00025748 0.00025748] (fitness = 0.9989676194586017))
# Ciclo 25, Mejor solucion del ciclo = [-1.3626269e-06 -1.3626269e-06] (fitness = 0.9999945494232312))
# Ciclo 30, Mejor solucion del ciclo = [-1.3626269e-06 -1.3626269e-06] (fitness = 0.9999945494232312))
# Ciclo 35, Mejor solucion del ciclo = [9.21741346e-08 9.21741346e-08] (fitness = 0.9999996313031438))
# Ciclo 40, Mejor solucion del ciclo = [-1.1265166e-08 -1.1265166e-08] (fitness = 0.999999954939333))
# Ciclo 45, Mejor solucion del ciclo = [1.53965233e-09 1.53965233e-09] (fitness = 0.9999999938413926))
# Mejor solucion encontrada por ABC: [-3.57480958e-10 -3.57480958e-10], fitness = 0.9999999985700758. Tomo 0.05418872833251953 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.06730352 0.06730352] (fitness = 0.668172941612434))
# Ciclo 5, Mejor solucion del ciclo = [-0.01534766 -0.01534766] (fitness = 0.9311886125381802))
# Ciclo 10, Mejor solucion del ciclo = [0.0032084 0.0032084] (fitness = 0.9867949501926448))
# Ciclo 15, Mejor solucion del ciclo = [-0.00015239 -0.00015239] (fitness = 0.9993895641661711))
# Ciclo 20, Mejor solucion del ciclo = [1.05226637e-05 1.05226637e-05] (fitness = 0.9999579052201527))
# Ciclo 25, Mejor solucion del ciclo = [-2.03506568e-06 -2.03506568e-06] (fitness = 0.9999918595829892))
# Ciclo 30, Mejor solucion del ciclo = [6.24065288e-08 6.24065288e-08] (fitness = 0.9999997503737422))
# Ciclo 35, Mejor solucion del ciclo = [-4.44754784e-09 -4.44754784e-09] (fitness = 0.9999999822098075))
# Ciclo 40, Mejor solucion del ciclo = [1.41149422e-10 1.41149422e-10] (fitness = 0.9999999994354032))
# Ciclo 45, Mejor solucion del ciclo = [-2.98245281e-11 -2.98245281e-11] (fitness = 0.9999999998807039))
# Mejor solucion encontrada por ABC: [-6.70074797e-13 -6.70074797e-13], fitness = 0.9999999999973217. Tomo 0.05304837226867676 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.27777845 0.27777845] (fitness = 0.25262056271720656))
# Ciclo 5, Mejor solucion del ciclo = [0.02876379 0.02876379] (fitness = 0.8630817613873611))
# Ciclo 10, Mejor solucion del ciclo = [0.00429099 0.00429099] (fitness = 0.9821790355837805))
# Ciclo 15, Mejor solucion del ciclo = [3.08564871e-05 3.08564871e-05] (fitness = 0.9998765385892607))
# Ciclo 20, Mejor solucion del ciclo = [-1.79327323e-06 -1.79327323e-06] (fitness = 0.9999928267872696))
# Ciclo 25, Mejor solucion del ciclo = [-1.47348251e-08 -1.47348251e-08] (fitness = 0.9999999410606927))
# Ciclo 30, Mejor solucion del ciclo = [1.04735159e-08 1.04735159e-08] (fitness = 0.9999999581059313))
# Ciclo 35, Mejor solucion del ciclo = [6.8306017e-09 6.8306017e-09] (fitness = 0.9999999726775916))
# Ciclo 40, Mejor solucion del ciclo = [-7.3322817e-10 -7.3322817e-10] (fitness = 0.9999999970670896))
# Ciclo 45, Mejor solucion del ciclo = [-7.43527499e-12 -7.43527499e-12] (fitness = 0.9999999999702607))
# Mejor solucion encontrada por ABC: [1.57871414e-13 1.57871414e-13], fitness = 0.9999999999993681. Tomo 0.06184530258178711 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.45098885 0.45098885] (fitness = 0.19771934460324359))
# Ciclo 5, Mejor solucion del ciclo = [0.0072341 0.0072341] (fitness = 0.9692537808999815))
# Ciclo 10, Mejor solucion del ciclo = [0.00046914 0.00046914] (fitness = 0.9981152619110705))
# Ciclo 15, Mejor solucion del ciclo = [-6.16074367e-05 -6.16074367e-05] (fitness = 0.9997534289309747))
# Ciclo 20, Mejor solucion del ciclo = [-1.44497071e-06 -1.44497071e-06] (fitness = 0.9999942200393817))
# Ciclo 25, Mejor solucion del ciclo = [-1.32493564e-06 -1.32493564e-06] (fitness = 0.9999947001920212))
# Ciclo 30, Mejor solucion del ciclo = [1.21594571e-07 1.21594571e-07] (fitness = 0.999999513621164))
# Ciclo 35, Mejor solucion del ciclo = [7.95186605e-11 7.95186605e-11] (fitness = 0.999999999681926))
# Ciclo 40, Mejor solucion del ciclo = [7.95186605e-11 7.95186605e-11] (fitness = 0.999999999681926))
# Ciclo 45, Mejor solucion del ciclo = [-1.11818089e-12 -1.11818089e-12] (fitness = 0.9999999999955276))
# Mejor solucion encontrada por ABC: [-1.67864376e-13 -1.67864376e-13], fitness = 0.999999999999329. Tomo 0.05245852470397949 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.12235594 0.12235594] (fitness = 0.46514076307756774))
# Ciclo 5, Mejor solucion del ciclo = [0.05370051 0.05370051] (fitness = 0.7338471498425545))
# Ciclo 10, Mejor solucion del ciclo = [-0.00115494 -0.00115494] (fitness = 0.9953311097928145))
# Ciclo 15, Mejor solucion del ciclo = [-9.29851859e-05 -9.29851859e-05] (fitness = 0.9996277374165308))
# Ciclo 20, Mejor solucion del ciclo = [-3.5014245e-06 -3.5014245e-06] (fitness = 0.9999859938452316))
# Ciclo 25, Mejor solucion del ciclo = [2.26962624e-06 2.26962624e-06] (fitness = 0.9999909213031463))
# Ciclo 30, Mejor solucion del ciclo = [-8.87332642e-08 -8.87332642e-08] (fitness = 0.9999996450666505))
# Ciclo 35, Mejor solucion del ciclo = [-7.44231671e-10 -7.44231671e-10] (fitness = 0.9999999970230715))
# Ciclo 40, Mejor solucion del ciclo = [7.0123266e-12 7.0123266e-12] (fitness = 0.9999999999719518))
# Ciclo 45, Mejor solucion del ciclo = [-3.59278646e-12 -3.59278646e-12] (fitness = 0.9999999999856297))
# Mejor solucion encontrada por ABC: [-2.39725684e-13 -2.39725684e-13], fitness = 0.9999999999990412. Tomo 0.07089090347290039 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.09518874 0.09518874] (fitness = 0.5523863786248296))
# Ciclo 5, Mejor solucion del ciclo = [-0.00106875 -0.00106875] (fitness = 0.995682872347956))
# Ciclo 10, Mejor solucion del ciclo = [-0.00014206 -0.00014206] (fitness = 0.9994310168313434))
# Ciclo 15, Mejor solucion del ciclo = [-0.00014206 -0.00014206] (fitness = 0.9994310168313434))
# Ciclo 20, Mejor solucion del ciclo = [-1.50472826e-06 -1.50472826e-06] (fitness = 0.9999939810025864))
# Ciclo 25, Mejor solucion del ciclo = [1.98106099e-07 1.98106099e-07] (fitness = 0.9999992075741422))
# Ciclo 30, Mejor solucion del ciclo = [1.22467543e-08 1.22467543e-08] (fitness = 0.9999999510129796))
# Ciclo 35, Mejor solucion del ciclo = [-3.87461352e-11 -3.87461352e-11] (fitness = 0.9999999998450169))
# Ciclo 40, Mejor solucion del ciclo = [5.42653642e-12 5.42653642e-12] (fitness = 0.9999999999782934))
# Ciclo 45, Mejor solucion del ciclo = [-4.14359717e-13 -4.14359717e-13] (fitness = 0.9999999999983449))
# Mejor solucion encontrada por ABC: [-5.37989559e-14 -5.37989559e-14], fitness = 0.9999999999997837. Tomo 0.09297704696655273 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.45098885 0.45098885] (fitness = 0.19771934460324359))
# Ciclo 5, Mejor solucion del ciclo = [0.03017659 0.03017659] (fitness = 0.8557072441064107))
# Ciclo 10, Mejor solucion del ciclo = [0.00063768 0.00063768] (fitness = 0.9974342067496176))
# Ciclo 15, Mejor solucion del ciclo = [-2.59900806e-06 -2.59900806e-06] (fitness = 0.9999896037161041))
# Ciclo 20, Mejor solucion del ciclo = [-2.59900806e-06 -2.59900806e-06] (fitness = 0.9999896037161041))
# Ciclo 25, Mejor solucion del ciclo = [-6.32498321e-07 -6.32498321e-07] (fitness = 0.9999974699918107))
# Ciclo 30, Mejor solucion del ciclo = [-1.03308731e-07 -1.03308731e-07] (fitness = 0.9999995867646805))
# Ciclo 35, Mejor solucion del ciclo = [7.50451562e-09 7.50451562e-09] (fitness = 0.9999999699819377))
# Ciclo 40, Mejor solucion del ciclo = [-2.97959038e-10 -2.97959038e-10] (fitness = 0.9999999988081645))
# Ciclo 45, Mejor solucion del ciclo = [4.94529054e-14 4.94529054e-14] (fitness = 0.9999999999998015))
# Mejor solucion encontrada por ABC: [4.94529054e-14 4.94529054e-14], fitness = 0.9999999999998015. Tomo 0.07135224342346191 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.06598619 0.06598619] (fitness = 0.6742962260965353))
# Ciclo 5, Mejor solucion del ciclo = [0.04497562 0.04497562] (fitness = 0.7783297990450534))
# Ciclo 10, Mejor solucion del ciclo = [0.04133321 0.04133321] (fitness = 0.7972607122752426))
# Ciclo 15, Mejor solucion del ciclo = [-0.00077304 -0.00077304] (fitness = 0.9968857434587697))
# Ciclo 20, Mejor solucion del ciclo = [8.68514141e-06 8.68514141e-06] (fitness = 0.9999652566242582))
# Ciclo 25, Mejor solucion del ciclo = [8.68514141e-06 8.68514141e-06] (fitness = 0.9999652566242582))
# Ciclo 30, Mejor solucion del ciclo = [8.68514141e-06 8.68514141e-06] (fitness = 0.9999652566242582))
# Ciclo 35, Mejor solucion del ciclo = [-5.71554526e-07 -5.71554526e-07] (fitness = 0.999997713769725))
# Ciclo 40, Mejor solucion del ciclo = [-1.86757321e-08 -1.86757321e-08] (fitness = 0.9999999252970591))
# Ciclo 45, Mejor solucion del ciclo = [-1.85739911e-09 -1.85739911e-09] (fitness = 0.9999999925704022))
# Mejor solucion encontrada por ABC: [4.81870676e-10 4.81870676e-10], fitness = 0.9999999980725183. Tomo 0.06145024299621582 seg
# Iniciando optimizacion con Algoritmo ABC
# Mejor solucion inicial = [0.45098885 0.45098885], fitness = 0.19771934460324359
# Ciclo 0, Mejor solucion del ciclo = [0.45098885 0.45098885] (fitness = 0.19771934460324359))
# Ciclo 5, Mejor solucion del ciclo = [0.15071933 0.15071933] (fitness = 0.3970229348786106))
# Ciclo 10, Mejor solucion del ciclo = [0.0394342 0.0394342] (fitness = 0.8071840299203976))
# Ciclo 15, Mejor solucion del ciclo = [0.00204659 0.00204659] (fitness = 0.9916607304447895))
# Ciclo 20, Mejor solucion del ciclo = [-6.94568042e-06 -6.94568042e-06] (fitness = 0.9999722154810999))
# Ciclo 25, Mejor solucion del ciclo = [3.70263983e-06 3.70263983e-06] (fitness = 0.9999851889299122))
# Ciclo 30, Mejor solucion del ciclo = [-9.16241741e-08 -9.16241741e-08] (fitness = 0.9999996335029919))
# Ciclo 35, Mejor solucion del ciclo = [3.26938279e-09 3.26938279e-09] (fitness = 0.9999999869224683))
# Ciclo 40, Mejor solucion del ciclo = [1.67815575e-10 1.67815575e-10] (fitness = 0.9999999993287365))
# Ciclo 45, Mejor solucion del ciclo = [-1.8853134e-11 -1.8853134e-11] (fitness = 0.999999999924587))
# Mejor solucion encontrada por ABC: [-4.93606116e-12 -4.93606116e-12], fitness = 0.9999999999802545. Tomo 0.05604362487792969 seg

# %%
for index, partial_total in enumerate(total_abc, start = 1):
  print('Combinación ', index)
  partial = np.array(partial_total)
  print('Media: ', partial.mean())
  print('Desviación estándar: ', partial.std())
# Out:
# Combinación  1
# Media:  0.8887571223491235
# Desviación estándar:  0.09260621185744738
# Combinación  2
# Media:  0.9999234605265459
# Desviación estándar:  0.000192215883517
# Combinación  3
# Media:  0.9999999996617248
# Desviación estándar:  6.794091212029528e-10

# %% [markdown]
# * Combinación 1 es limit = 1, combinación 2 es limit = 10 y combinación 3 es limit = 50
# * A más explotativo mejor fitness

# %% [markdown]
# <b>2) Ejecute 10 veces PSO en la funcion ACkley para cada combinacion de parametros:</b>
#
#       - PN = 5
#       - max_iter = 50
#       - Xmin = [-20, -20]
#       - Xmax = [20, 20]
#       - w  = {0.01, 0.1, 1}
#       - phi1 = {0.1, 2, 10}
#       - phi2 = {0.1, 2, 10}
#
#       Registre la media del fitness de la mejor solucion encontrada en cada combinacion de parametros y analise los resultados y responda lo  siguiente:
#
#       * ¿Qué configuracion tiende a ofrecer mejores resultados?
#       * ¿Cómo influye "la fuerza inercial", "el aprendizaje cognitivo" y "el aprendizaje social" en la busqueda de optimos.
#       * Compare los resultados contra los encontrados por ABC en dicha funcion (ACkley)

# %%
# instancia poblacion de particulas para PSO
pn = 5
max_iter = 50
coord_min = [-20, -20]
coord_max = [20, 20]

initial_particles = PSO_particles(pn, coord_min, coord_max)

# %%
w = {0.01, 0.1, 1}
phi1 = {0.1, 2, 10}
phi2 = {0.1, 2, 10}
total_pso = []
j = 0
for iner in w:
  for p1 in phi1:
    for p2 in phi2:
      total_pso.append([])
      for i in range(10):
        # instancia optimizador PSO para minimizar la funcion ackley
        pso_optimizer_ackley = PSO(ackley, initial_particles, 0.01, 1, 1, max_iter)   # w= .01,  phi1=1, phi2=1, iterations=50
        best_solution, best_fitness, history_bestfitness, history_bestsolution = pso_optimizer_ackley.optimize()
        # ackley_best_solution = ackley(best_solution)
        total_pso[j].append(best_fitness)
      j = j + 1
# Out:
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.00349809 -0.00349809] (fitness = 0.9855674237888759))
# Ciclo 10, Mejor solucion del ciclo = [-2.42838455e-05 -2.42838455e-05] (fitness = 0.9999028426525823))
# Ciclo 15, Mejor solucion del ciclo = [-7.54229685e-06 -7.54229685e-06] (fitness = 0.999969828693353))
# Ciclo 20, Mejor solucion del ciclo = [-7.53347488e-06 -7.53347488e-06] (fitness = 0.9999698639861799))
# Ciclo 25, Mejor solucion del ciclo = [-7.53301139e-06 -7.53301139e-06] (fitness = 0.9999698658404119))
# Ciclo 30, Mejor solucion del ciclo = [-7.5330032e-06 -7.5330032e-06] (fitness = 0.9999698658731904))
# Ciclo 35, Mejor solucion del ciclo = [-7.5330032e-06 -7.5330032e-06] (fitness = 0.9999698658731939))
# Ciclo 40, Mejor solucion del ciclo = [-7.5330032e-06 -7.5330032e-06] (fitness = 0.9999698658731939))
# Ciclo 45, Mejor solucion del ciclo = [-7.5330032e-06 -7.5330032e-06] (fitness = 0.9999698658731939))
# Mejor solucion encontrada por PSO: [-7.5330032e-06 -7.5330032e-06], fitness = 0.9999698658731939. Tomo 0.02458500862121582 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [-0.08995949 -0.08995949] (fitness = 0.5720264223253552))
# Ciclo 5, Mejor solucion del ciclo = [0.03163153 0.03163153] (fitness = 0.8480948141426673))
# Ciclo 10, Mejor solucion del ciclo = [0.03052183 0.03052183] (fitness = 0.8539023627992924))
# Ciclo 15, Mejor solucion del ciclo = [0.00102452 0.00102452] (fitness = 0.9958632124867024))
# Ciclo 20, Mejor solucion del ciclo = [0.00070758 0.00070758] (fitness = 0.9971511722480159))
# Ciclo 25, Mejor solucion del ciclo = [0.00070676 0.00070676] (fitness = 0.9971544631918561))
# Ciclo 30, Mejor solucion del ciclo = [0.00070676 0.00070676] (fitness = 0.9971544686491041))
# Ciclo 35, Mejor solucion del ciclo = [0.00070676 0.00070676] (fitness = 0.9971544686553385))
# Ciclo 40, Mejor solucion del ciclo = [0.00070676 0.00070676] (fitness = 0.9971544686736776))
# Ciclo 45, Mejor solucion del ciclo = [0.00070676 0.00070676] (fitness = 0.9971544686736776))
# Mejor solucion encontrada por PSO: [0.00070676 0.00070676], fitness = 0.9971544686736776. Tomo 0.0169985294342041 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.04785326 -0.04785326] (fitness = 0.7635030002853396))
# Ciclo 10, Mejor solucion del ciclo = [-0.00357023 -0.00357023] (fitness = 0.9852608282710581))
# Ciclo 15, Mejor solucion del ciclo = [-0.00352946 -0.00352946] (fitness = 0.9854341342205689))
# Ciclo 20, Mejor solucion del ciclo = [-0.00350817 -0.00350817] (fitness = 0.9855246038071789))
# Ciclo 25, Mejor solucion del ciclo = [-0.00350817 -0.00350817] (fitness = 0.9855246038071896))
# Ciclo 30, Mejor solucion del ciclo = [-0.00350817 -0.00350817] (fitness = 0.9855246043226241))
# Ciclo 35, Mejor solucion del ciclo = [-0.00350817 -0.00350817] (fitness = 0.985524604367526))
# Ciclo 40, Mejor solucion del ciclo = [-0.00350817 -0.00350817] (fitness = 0.985524604367526))
# Ciclo 45, Mejor solucion del ciclo = [-0.00350817 -0.00350817] (fitness = 0.985524604367526))
# Mejor solucion encontrada por PSO: [-0.00350817 -0.00350817], fitness = 0.985524604367526. Tomo 0.01668572425842285 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.04905218 0.04905218] (fitness = 0.7573667883929116))
# Ciclo 10, Mejor solucion del ciclo = [0.0168756 0.0168756] (fitness = 0.9236917909836447))
# Ciclo 15, Mejor solucion del ciclo = [0.00199282 0.00199282] (fitness = 0.9918836321184306))
# Ciclo 20, Mejor solucion del ciclo = [0.00198462 0.00198462] (fitness = 0.9919176107495314))
# Ciclo 25, Mejor solucion del ciclo = [0.0019846 0.0019846] (fitness = 0.9919176935728745))
# Ciclo 30, Mejor solucion del ciclo = [0.0019846 0.0019846] (fitness = 0.9919176935728745))
# Ciclo 35, Mejor solucion del ciclo = [0.0019846 0.0019846] (fitness = 0.9919176935774286))
# Ciclo 40, Mejor solucion del ciclo = [0.0019846 0.0019846] (fitness = 0.991917693596485))
# Ciclo 45, Mejor solucion del ciclo = [0.0019846 0.0019846] (fitness = 0.9919176935965954))
# Mejor solucion encontrada por PSO: [0.0019846 0.0019846], fitness = 0.9919176935965954. Tomo 0.02301812171936035 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.04059436 0.04059436] (fitness = 0.8011181096980026))
# Ciclo 10, Mejor solucion del ciclo = [-0.00251838 -0.00251838] (fitness = 0.9896960348266247))
# Ciclo 15, Mejor solucion del ciclo = [-4.35405717e-05 -4.35405717e-05] (fitness = 0.9998257671126299))
# Ciclo 20, Mejor solucion del ciclo = [-1.02165544e-05 -1.02165544e-05] (fitness = 0.9999591298941934))
# Ciclo 25, Mejor solucion del ciclo = [1.04221185e-06 1.04221185e-06] (fitness = 0.9999958311121413))
# Ciclo 30, Mejor solucion del ciclo = [9.89235008e-07 9.89235008e-07] (fitness = 0.999996043023514))
# Ciclo 35, Mejor solucion del ciclo = [9.89231998e-07 9.89231998e-07] (fitness = 0.9999960430355509))
# Ciclo 40, Mejor solucion del ciclo = [9.89231998e-07 9.89231998e-07] (fitness = 0.9999960430355509))
# Ciclo 45, Mejor solucion del ciclo = [9.89231982e-07 9.89231982e-07] (fitness = 0.9999960430356148))
# Mejor solucion encontrada por PSO: [9.89231982e-07 9.89231982e-07], fitness = 0.9999960430356148. Tomo 0.03432464599609375 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.00218116 -0.00218116] (fitness = 0.9911018879912592))
# Ciclo 10, Mejor solucion del ciclo = [-4.43769105e-05 -4.43769105e-05] (fitness = 0.999822419019424))
# Ciclo 15, Mejor solucion del ciclo = [-4.43769052e-05 -4.43769052e-05] (fitness = 0.9998224190408401))
# Ciclo 20, Mejor solucion del ciclo = [-4.43768769e-05 -4.43768769e-05] (fitness = 0.9998224191541275))
# Ciclo 25, Mejor solucion del ciclo = [-4.43768748e-05 -4.43768748e-05] (fitness = 0.9998224191624547))
# Ciclo 30, Mejor solucion del ciclo = [-4.43768748e-05 -4.43768748e-05] (fitness = 0.9998224191624583))
# Ciclo 35, Mejor solucion del ciclo = [-4.43768748e-05 -4.43768748e-05] (fitness = 0.9998224191625329))
# Ciclo 40, Mejor solucion del ciclo = [-4.43768748e-05 -4.43768748e-05] (fitness = 0.9998224191625329))
# Ciclo 45, Mejor solucion del ciclo = [-4.43768748e-05 -4.43768748e-05] (fitness = 0.9998224191625329))
# Mejor solucion encontrada por PSO: [-4.43768748e-05 -4.43768748e-05], fitness = 0.9998224191625329. Tomo 0.019635677337646484 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.06256059 0.06256059] (fitness = 0.6904703482939175))
# Ciclo 10, Mejor solucion del ciclo = [0.01041894 0.01041894] (fitness = 0.954700655427378))
# Ciclo 15, Mejor solucion del ciclo = [0.01040819 0.01040819] (fitness = 0.954750713403095))
# Ciclo 20, Mejor solucion del ciclo = [0.01040809 0.01040809] (fitness = 0.9547511765083954))
# Ciclo 25, Mejor solucion del ciclo = [0.01040808 0.01040808] (fitness = 0.9547512274794441))
# Ciclo 30, Mejor solucion del ciclo = [0.01040808 0.01040808] (fitness = 0.9547512274797096))
# Ciclo 35, Mejor solucion del ciclo = [0.01040808 0.01040808] (fitness = 0.9547512275485005))
# Ciclo 40, Mejor solucion del ciclo = [0.01040808 0.01040808] (fitness = 0.9547512275485005))
# Ciclo 45, Mejor solucion del ciclo = [0.01040808 0.01040808] (fitness = 0.9547512275485005))
# Mejor solucion encontrada por PSO: [0.01040808 0.01040808], fitness = 0.9547512275485005. Tomo 0.02225971221923828 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.08214101 0.08214101] (fitness = 0.6031890383609961))
# Ciclo 10, Mejor solucion del ciclo = [0.00159836 0.00159836] (fitness = 0.9935128796686593))
# Ciclo 15, Mejor solucion del ciclo = [0.00047741 0.00047741] (fitness = 0.998081924149668))
# Ciclo 20, Mejor solucion del ciclo = [0.00047624 0.00047624] (fitness = 0.9980866206770073))
# Ciclo 25, Mejor solucion del ciclo = [0.00047624 0.00047624] (fitness = 0.9980866209282059))
# Ciclo 30, Mejor solucion del ciclo = [0.00047624 0.00047624] (fitness = 0.9980866209282594))
# Ciclo 35, Mejor solucion del ciclo = [0.00047624 0.00047624] (fitness = 0.9980866209284209))
# Ciclo 40, Mejor solucion del ciclo = [0.00047624 0.00047624] (fitness = 0.9980866209284209))
# Ciclo 45, Mejor solucion del ciclo = [0.00047624 0.00047624] (fitness = 0.9980866209284209))
# Mejor solucion encontrada por PSO: [0.00047624 0.00047624], fitness = 0.9980866209284209. Tomo 0.019695520401000977 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.00196939 -0.00196939] (fitness = 0.9919807031165289))
# Ciclo 10, Mejor solucion del ciclo = [8.23084086e-06 8.23084086e-06] (fitness = 0.9999670741127576))
# Ciclo 15, Mejor solucion del ciclo = [-3.37224126e-08 -3.37224126e-08] (fitness = 0.9999998651103081))
# Ciclo 20, Mejor solucion del ciclo = [-3.83930039e-09 -3.83930039e-09] (fitness = 0.999999984642798))
# Ciclo 25, Mejor solucion del ciclo = [-2.17336041e-10 -2.17336041e-10] (fitness = 0.999999999130655))
# Ciclo 30, Mejor solucion del ciclo = [9.80847161e-12 9.80847161e-12] (fitness = 0.9999999999607678))
# Ciclo 35, Mejor solucion del ciclo = [5.89215526e-12 5.89215526e-12] (fitness = 0.9999999999764317))
# Ciclo 40, Mejor solucion del ciclo = [5.89149838e-12 5.89149838e-12] (fitness = 0.9999999999764353))
# Ciclo 45, Mejor solucion del ciclo = [5.89149953e-12 5.89149953e-12] (fitness = 0.9999999999764353))
# Mejor solucion encontrada por PSO: [5.89149953e-12 5.89149953e-12], fitness = 0.9999999999764353. Tomo 0.023032426834106445 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.0098957 0.0098957] (fitness = 0.9571290104757341))
# Ciclo 10, Mejor solucion del ciclo = [0.00197109 0.00197109] (fitness = 0.9919736937610834))
# Ciclo 15, Mejor solucion del ciclo = [2.10120874e-05 2.10120874e-05] (fitness = 0.9999159352047307))
# Ciclo 20, Mejor solucion del ciclo = [2.05199757e-05 2.05199757e-05] (fitness = 0.9999179044124735))
# Ciclo 25, Mejor solucion del ciclo = [2.05199327e-05 2.05199327e-05] (fitness = 0.9999179045848859))
# Ciclo 30, Mejor solucion del ciclo = [2.05199327e-05 2.05199327e-05] (fitness = 0.9999179045848859))
# Ciclo 35, Mejor solucion del ciclo = [2.05199327e-05 2.05199327e-05] (fitness = 0.9999179045848859))
# Ciclo 40, Mejor solucion del ciclo = [2.05199327e-05 2.05199327e-05] (fitness = 0.9999179045848859))
# Ciclo 45, Mejor solucion del ciclo = [2.05199326e-05 2.05199326e-05] (fitness = 0.999917904585021))
# Mejor solucion encontrada por PSO: [2.05199326e-05 2.05199326e-05], fitness = 0.999917904585021. Tomo 0.02118682861328125 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.02019002 0.02019002] (fitness = 0.9071505625073816))
# Ciclo 10, Mejor solucion del ciclo = [0.00029484 0.00029484] (fitness = 0.9988173924600218))
# Ciclo 15, Mejor solucion del ciclo = [0.00026083 0.00026083] (fitness = 0.9989541680605402))
# Ciclo 20, Mejor solucion del ciclo = [0.00026072 0.00026072] (fitness = 0.9989545846117099))
# Ciclo 25, Mejor solucion del ciclo = [0.0002607 0.0002607] (fitness = 0.9989546571492965))
# Ciclo 30, Mejor solucion del ciclo = [0.0002607 0.0002607] (fitness = 0.99895465716121))
# Ciclo 35, Mejor solucion del ciclo = [0.0002607 0.0002607] (fitness = 0.9989546571614777))
# Ciclo 40, Mejor solucion del ciclo = [0.0002607 0.0002607] (fitness = 0.9989546571614777))
# Ciclo 45, Mejor solucion del ciclo = [0.0002607 0.0002607] (fitness = 0.9989546571614777))
# Mejor solucion encontrada por PSO: [0.0002607 0.0002607], fitness = 0.9989546571614777. Tomo 0.02651071548461914 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.0270725 0.0270725] (fitness = 0.871879855718743))
# Ciclo 10, Mejor solucion del ciclo = [0.02702383 0.02702383] (fitness = 0.8721325114040503))
# Ciclo 15, Mejor solucion del ciclo = [0.02700848 0.02700848] (fitness = 0.8722121351867507))
# Ciclo 20, Mejor solucion del ciclo = [0.02700847 0.02700847] (fitness = 0.8722122098873459))
# Ciclo 25, Mejor solucion del ciclo = [0.02700847 0.02700847] (fitness = 0.8722122101538707))
# Ciclo 30, Mejor solucion del ciclo = [0.02700847 0.02700847] (fitness = 0.8722122101538707))
# Ciclo 35, Mejor solucion del ciclo = [0.02700847 0.02700847] (fitness = 0.8722122101538707))
# Ciclo 40, Mejor solucion del ciclo = [0.02700847 0.02700847] (fitness = 0.8722122101538707))
# Ciclo 45, Mejor solucion del ciclo = [0.02700847 0.02700847] (fitness = 0.8722122101538707))
# Mejor solucion encontrada por PSO: [0.02700847 0.02700847], fitness = 0.8722122101538707. Tomo 0.024528026580810547 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.00315234 0.00315234] (fitness = 0.9870318467981971))
# Ciclo 10, Mejor solucion del ciclo = [0.00085165 0.00085165] (fitness = 0.9965665951955064))
# Ciclo 15, Mejor solucion del ciclo = [0.00084842 0.00084842] (fitness = 0.9965797433580097))
# Ciclo 20, Mejor solucion del ciclo = [0.00084842 0.00084842] (fitness = 0.9965797433771687))
# Ciclo 25, Mejor solucion del ciclo = [0.00084842 0.00084842] (fitness = 0.9965797433915177))
# Ciclo 30, Mejor solucion del ciclo = [0.00084842 0.00084842] (fitness = 0.9965797433915177))
# Ciclo 35, Mejor solucion del ciclo = [0.00084842 0.00084842] (fitness = 0.9965797433915177))
# Ciclo 40, Mejor solucion del ciclo = [0.00084842 0.00084842] (fitness = 0.9965797433915177))
# Ciclo 45, Mejor solucion del ciclo = [0.00084842 0.00084842] (fitness = 0.9965797433915177))
# Mejor solucion encontrada por PSO: [0.00084842 0.00084842], fitness = 0.9965797433915177. Tomo 0.02201986312866211 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.00097416 0.00097416] (fitness = 0.9960683473195467))
# Ciclo 10, Mejor solucion del ciclo = [3.84015589e-05 3.84015589e-05] (fitness = 0.9998463388432932))
# Ciclo 15, Mejor solucion del ciclo = [-2.90765209e-06 -2.90765209e-06] (fitness = 0.9999883690766588))
# Ciclo 20, Mejor solucion del ciclo = [-6.41150522e-08 -6.41150522e-08] (fitness = 0.9999997435396382))
# Ciclo 25, Mejor solucion del ciclo = [-2.50340407e-10 -2.50340407e-10] (fitness = 0.9999999989986397))
# Ciclo 30, Mejor solucion del ciclo = [-9.39102673e-12 -9.39102673e-12] (fitness = 0.9999999999624376))
# Ciclo 35, Mejor solucion del ciclo = [-2.61869519e-12 -2.61869519e-12] (fitness = 0.999999999989527))
# Ciclo 40, Mejor solucion del ciclo = [-2.60058126e-12 -2.60058126e-12] (fitness = 0.9999999999895981))
# Ciclo 45, Mejor solucion del ciclo = [-2.60058724e-12 -2.60058724e-12] (fitness = 0.9999999999895981))
# Mejor solucion encontrada por PSO: [-2.60066112e-12 -2.60066112e-12], fitness = 0.9999999999895981. Tomo 0.021279573440551758 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.00128902 -0.00128902] (fitness = 0.9947827774930635))
# Ciclo 10, Mejor solucion del ciclo = [-0.00038944 -0.00038944] (fitness = 0.9984365928568496))
# Ciclo 15, Mejor solucion del ciclo = [-0.00038938 -0.00038938] (fitness = 0.9984368454216147))
# Ciclo 20, Mejor solucion del ciclo = [-0.00038938 -0.00038938] (fitness = 0.9984368481882246))
# Ciclo 25, Mejor solucion del ciclo = [-0.00038938 -0.00038938] (fitness = 0.9984368481882246))
# Ciclo 30, Mejor solucion del ciclo = [-0.00038938 -0.00038938] (fitness = 0.9984368481883106))
# Ciclo 35, Mejor solucion del ciclo = [-0.00038938 -0.00038938] (fitness = 0.9984368481883106))
# Ciclo 40, Mejor solucion del ciclo = [-0.00038938 -0.00038938] (fitness = 0.9984368481883106))
# Ciclo 45, Mejor solucion del ciclo = [-0.00038938 -0.00038938] (fitness = 0.9984368481883106))
# Mejor solucion encontrada por PSO: [-0.00038938 -0.00038938], fitness = 0.9984368481883212. Tomo 0.02470564842224121 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.00440734 -0.00440734] (fitness = 0.9816783548156782))
# Ciclo 10, Mejor solucion del ciclo = [-8.61886392e-06 -8.61886392e-06] (fitness = 0.9999655217769352))
# Ciclo 15, Mejor solucion del ciclo = [-7.42043444e-06 -7.42043444e-06] (fitness = 0.9999703162109418))
# Ciclo 20, Mejor solucion del ciclo = [-7.40250691e-06 -7.40250691e-06] (fitness = 0.999970387930935))
# Ciclo 25, Mejor solucion del ciclo = [-7.402053e-06 -7.402053e-06] (fitness = 0.9999703897468379))
# Ciclo 30, Mejor solucion del ciclo = [-7.402053e-06 -7.402053e-06] (fitness = 0.9999703897468379))
# Ciclo 35, Mejor solucion del ciclo = [-7.40205296e-06 -7.40205296e-06] (fitness = 0.9999703897469872))
# Ciclo 40, Mejor solucion del ciclo = [-7.40205296e-06 -7.40205296e-06] (fitness = 0.9999703897469872))
# Ciclo 45, Mejor solucion del ciclo = [-7.40205296e-06 -7.40205296e-06] (fitness = 0.9999703897469872))
# Mejor solucion encontrada por PSO: [-7.40205296e-06 -7.40205296e-06], fitness = 0.9999703897469872. Tomo 0.021014690399169922 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.06525209 0.06525209] (fitness = 0.6777320765693081))
# Ciclo 10, Mejor solucion del ciclo = [0.04682263 0.04682263] (fitness = 0.7687980098905539))
# Ciclo 15, Mejor solucion del ciclo = [0.04682248 0.04682248] (fitness = 0.7687987547689763))
# Ciclo 20, Mejor solucion del ciclo = [0.04682215 0.04682215] (fitness = 0.7688004914161642))
# Ciclo 25, Mejor solucion del ciclo = [0.04682215 0.04682215] (fitness = 0.76880049141933))
# Ciclo 30, Mejor solucion del ciclo = [0.04682215 0.04682215] (fitness = 0.7688004921470462))
# Ciclo 35, Mejor solucion del ciclo = [0.04682215 0.04682215] (fitness = 0.7688004921470465))
# Ciclo 40, Mejor solucion del ciclo = [0.04682215 0.04682215] (fitness = 0.7688004921470659))
# Ciclo 45, Mejor solucion del ciclo = [0.04682215 0.04682215] (fitness = 0.7688004921470685))
# Mejor solucion encontrada por PSO: [0.04682215 0.04682215], fitness = 0.7688004921470685. Tomo 0.024279356002807617 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.01865686 -0.01865686] (fitness = 0.9148462327590732))
# Ciclo 10, Mejor solucion del ciclo = [-0.01847629 -0.01847629] (fitness = 0.9157477598055987))
# Ciclo 15, Mejor solucion del ciclo = [-0.01847603 -0.01847603] (fitness = 0.915749052298627))
# Ciclo 20, Mejor solucion del ciclo = [-0.01847603 -0.01847603] (fitness = 0.9157490523678784))
# Ciclo 25, Mejor solucion del ciclo = [-0.01847603 -0.01847603] (fitness = 0.9157490523770718))
# Ciclo 30, Mejor solucion del ciclo = [-0.01847603 -0.01847603] (fitness = 0.9157490523770718))
# Ciclo 35, Mejor solucion del ciclo = [-0.01847603 -0.01847603] (fitness = 0.915749052377264))
# Ciclo 40, Mejor solucion del ciclo = [-0.01847603 -0.01847603] (fitness = 0.9157490523772814))
# Ciclo 45, Mejor solucion del ciclo = [-0.01847603 -0.01847603] (fitness = 0.9157490523772814))
# Mejor solucion encontrada por PSO: [-0.01847603 -0.01847603], fitness = 0.9157490523772814. Tomo 0.01982426643371582 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.03154086 -0.03154086] (fitness = 0.8485696404005892))
# Ciclo 10, Mejor solucion del ciclo = [-0.00126183 -0.00126183] (fitness = 0.9948940887639114))
# Ciclo 15, Mejor solucion del ciclo = [-0.00051372 -0.00051372] (fitness = 0.9979353498629007))
# Ciclo 20, Mejor solucion del ciclo = [-0.00050975 -0.00050975] (fitness = 0.9979513746820718))
# Ciclo 25, Mejor solucion del ciclo = [-0.00050975 -0.00050975] (fitness = 0.9979513747167428))
# Ciclo 30, Mejor solucion del ciclo = [-0.00050975 -0.00050975] (fitness = 0.997951376057017))
# Ciclo 35, Mejor solucion del ciclo = [-0.00050975 -0.00050975] (fitness = 0.997951376057017))
# Ciclo 40, Mejor solucion del ciclo = [-0.00050975 -0.00050975] (fitness = 0.997951376084863))
# Ciclo 45, Mejor solucion del ciclo = [-0.00050975 -0.00050975] (fitness = 0.9979513760848665))
# Mejor solucion encontrada por PSO: [-0.00050975 -0.00050975], fitness = 0.9979513760848665. Tomo 0.030461549758911133 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.0336972 0.0336972] (fitness = 0.8372664204028148))
# Ciclo 10, Mejor solucion del ciclo = [0.004594 0.004594] (fitness = 0.9808733006544589))
# Ciclo 15, Mejor solucion del ciclo = [0.00318841 0.00318841] (fitness = 0.986879457076264))
# Ciclo 20, Mejor solucion del ciclo = [0.00318812 0.00318812] (fitness = 0.9868806945622981))
# Ciclo 25, Mejor solucion del ciclo = [0.00318812 0.00318812] (fitness = 0.9868806947028537))
# Ciclo 30, Mejor solucion del ciclo = [0.00318812 0.00318812] (fitness = 0.9868806950824971))
# Ciclo 35, Mejor solucion del ciclo = [0.00318812 0.00318812] (fitness = 0.9868806950824971))
# Ciclo 40, Mejor solucion del ciclo = [0.00318812 0.00318812] (fitness = 0.9868806950824971))
# Ciclo 45, Mejor solucion del ciclo = [0.00318812 0.00318812] (fitness = 0.9868806950824971))
# Mejor solucion encontrada por PSO: [0.00318812 0.00318812], fitness = 0.9868806950824971. Tomo 0.02068781852722168 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.05058694 0.05058694] (fitness = 0.7495514033951294))
# Ciclo 10, Mejor solucion del ciclo = [-0.04379417 -0.04379417] (fitness = 0.7844526494728608))
# Ciclo 15, Mejor solucion del ciclo = [0.00068131 0.00068131] (fitness = 0.9972575733244426))
# Ciclo 20, Mejor solucion del ciclo = [3.21509363e-06 3.21509363e-06] (fitness = 0.9999871392403714))
# Ciclo 25, Mejor solucion del ciclo = [-8.17804199e-07 -8.17804199e-07] (fitness = 0.9999967287582882))
# Ciclo 30, Mejor solucion del ciclo = [5.25667106e-09 5.25667106e-09] (fitness = 0.9999999789733134))
# Ciclo 35, Mejor solucion del ciclo = [-3.28978042e-12 -3.28978042e-12] (fitness = 0.9999999999868412))
# Ciclo 40, Mejor solucion del ciclo = [-2.5492265e-13 -2.5492265e-13] (fitness = 0.9999999999989808))
# Ciclo 45, Mejor solucion del ciclo = [-2.45678875e-13 -2.45678875e-13] (fitness = 0.9999999999990163))
# Mejor solucion encontrada por PSO: [-2.45559464e-13 -2.45559464e-13], fitness = 0.9999999999990199. Tomo 0.020546674728393555 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.05115443 0.05115443] (fitness = 0.746673526840296))
# Ciclo 10, Mejor solucion del ciclo = [0.05030741 0.05030741] (fitness = 0.7509713970072742))
# Ciclo 15, Mejor solucion del ciclo = [0.05030616 0.05030616] (fitness = 0.750977736693039))
# Ciclo 20, Mejor solucion del ciclo = [0.05030616 0.05030616] (fitness = 0.7509777432987356))
# Ciclo 25, Mejor solucion del ciclo = [0.05030616 0.05030616] (fitness = 0.7509777460280082))
# Ciclo 30, Mejor solucion del ciclo = [0.05030616 0.05030616] (fitness = 0.7509777460282492))
# Ciclo 35, Mejor solucion del ciclo = [0.05030616 0.05030616] (fitness = 0.7509777460282524))
# Ciclo 40, Mejor solucion del ciclo = [0.05030616 0.05030616] (fitness = 0.7509777460282524))
# Ciclo 45, Mejor solucion del ciclo = [0.05030616 0.05030616] (fitness = 0.7509777460282524))
# Mejor solucion encontrada por PSO: [0.05030616 0.05030616], fitness = 0.7509777460282524. Tomo 0.026427268981933594 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.00752816 -0.00752816] (fitness = 0.9679337148578568))
# Ciclo 10, Mejor solucion del ciclo = [-0.00733443 -0.00733443] (fitness = 0.9688039499083806))
# Ciclo 15, Mejor solucion del ciclo = [0.00189003 0.00189003] (fitness = 0.992309232329936))
# Ciclo 20, Mejor solucion del ciclo = [-9.06486705e-05 -9.06486705e-05] (fitness = 0.9996370994423839))
# Ciclo 25, Mejor solucion del ciclo = [2.66991032e-07 2.66991032e-07] (fitness = 0.9999989320332167))
# Ciclo 30, Mejor solucion del ciclo = [3.16241877e-08 3.16241877e-08] (fitness = 0.9999998735032118))
# Ciclo 35, Mejor solucion del ciclo = [3.16175079e-08 3.16175079e-08] (fitness = 0.9999998735299318))
# Ciclo 40, Mejor solucion del ciclo = [3.15926441e-08 3.15926441e-08] (fitness = 0.9999998736293869))
# Ciclo 45, Mejor solucion del ciclo = [3.15926438e-08 3.15926438e-08] (fitness = 0.9999998736293905))
# Mejor solucion encontrada por PSO: [3.15926438e-08 3.15926438e-08], fitness = 0.9999998736293905. Tomo 0.01979970932006836 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.00480428 -0.00480428] (fitness = 0.9799636948521191))
# Ciclo 10, Mejor solucion del ciclo = [8.78835188e-05 8.78835188e-05] (fitness = 0.9996481784176496))
# Ciclo 15, Mejor solucion del ciclo = [-3.28346614e-06 -3.28346614e-06] (fitness = 0.9999868657337666))
# Ciclo 20, Mejor solucion del ciclo = [7.24492919e-09 7.24492919e-09] (fitness = 0.9999999710202823))
# Ciclo 25, Mejor solucion del ciclo = [-1.49260164e-09 -1.49260164e-09] (fitness = 0.999999994029594))
# Ciclo 30, Mejor solucion del ciclo = [-4.00300249e-10 -4.00300249e-10] (fitness = 0.9999999983987995))
# Ciclo 35, Mejor solucion del ciclo = [-3.99573203e-10 -3.99573203e-10] (fitness = 0.9999999984017092))
# Ciclo 40, Mejor solucion del ciclo = [-3.99542776e-10 -3.99542776e-10] (fitness = 0.99999999840183))
# Ciclo 45, Mejor solucion del ciclo = [-3.9954083e-10 -3.9954083e-10] (fitness = 0.9999999984018371))
# Mejor solucion encontrada por PSO: [-3.99540767e-10 -3.99540767e-10], fitness = 0.9999999984018371. Tomo 0.02064800262451172 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.07044648 0.07044648] (fitness = 0.6537885262264809))
# Ciclo 10, Mejor solucion del ciclo = [0.06839703 0.06839703] (fitness = 0.6631319999418641))
# Ciclo 15, Mejor solucion del ciclo = [0.06839428 0.06839428] (fitness = 0.6631446279485855))
# Ciclo 20, Mejor solucion del ciclo = [0.06839428 0.06839428] (fitness = 0.6631446372140164))
# Ciclo 25, Mejor solucion del ciclo = [0.06839428 0.06839428] (fitness = 0.6631446372140164))
# Ciclo 30, Mejor solucion del ciclo = [0.06839428 0.06839428] (fitness = 0.6631446372140424))
# Ciclo 35, Mejor solucion del ciclo = [0.06839428 0.06839428] (fitness = 0.6631446372141401))
# Ciclo 40, Mejor solucion del ciclo = [0.06839428 0.06839428] (fitness = 0.6631446372141401))
# Ciclo 45, Mejor solucion del ciclo = [0.06839428 0.06839428] (fitness = 0.6631446372141401))
# Mejor solucion encontrada por PSO: [0.06839428 0.06839428], fitness = 0.6631446372141401. Tomo 0.019740581512451172 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.00059005 0.00059005] (fitness = 0.9976268955898405))
# Ciclo 10, Mejor solucion del ciclo = [0.00043968 0.00043968] (fitness = 0.99823411306127))
# Ciclo 15, Mejor solucion del ciclo = [0.00043925 0.00043925] (fitness = 0.9982358598529824))
# Ciclo 20, Mejor solucion del ciclo = [4.37682312e-06 4.37682312e-06] (fitness = 0.9999824919938471))
# Ciclo 25, Mejor solucion del ciclo = [4.3621197e-06 4.3621197e-06] (fitness = 0.9999825508123114))
# Ciclo 30, Mejor solucion del ciclo = [4.36211937e-06 4.36211937e-06] (fitness = 0.9999825508136405))
# Ciclo 35, Mejor solucion del ciclo = [4.36211749e-06 4.36211749e-06] (fitness = 0.9999825508211373))
# Ciclo 40, Mejor solucion del ciclo = [4.36211737e-06 4.36211737e-06] (fitness = 0.9999825508216311))
# Ciclo 45, Mejor solucion del ciclo = [4.36211737e-06 4.36211737e-06] (fitness = 0.9999825508216382))
# Mejor solucion encontrada por PSO: [4.36211737e-06 4.36211737e-06], fitness = 0.9999825508216382. Tomo 0.023276805877685547 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.03789624 0.03789624] (fitness = 0.8152387656643396))
# Ciclo 10, Mejor solucion del ciclo = [0.03788667 0.03788667] (fitness = 0.8152889391599242))
# Ciclo 15, Mejor solucion del ciclo = [0.03788609 0.03788609] (fitness = 0.8152919571469616))
# Ciclo 20, Mejor solucion del ciclo = [0.03788608 0.03788608] (fitness = 0.815292021416645))
# Ciclo 25, Mejor solucion del ciclo = [0.03788608 0.03788608] (fitness = 0.8152920214881011))
# Ciclo 30, Mejor solucion del ciclo = [0.03788608 0.03788608] (fitness = 0.8152920214881566))
# Ciclo 35, Mejor solucion del ciclo = [0.03788608 0.03788608] (fitness = 0.8152920214881578))
# Ciclo 40, Mejor solucion del ciclo = [0.03788608 0.03788608] (fitness = 0.8152920214881578))
# Ciclo 45, Mejor solucion del ciclo = [0.03788608 0.03788608] (fitness = 0.8152920214881578))
# Mejor solucion encontrada por PSO: [0.03788608 0.03788608], fitness = 0.8152920214881578. Tomo 0.018277406692504883 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.00031526 -0.00031526] (fitness = 0.9987352752986297))
# Ciclo 10, Mejor solucion del ciclo = [7.73794391e-05 7.73794391e-05] (fitness = 0.9996902593339546))
# Ciclo 15, Mejor solucion del ciclo = [-2.4000079e-08 -2.4000079e-08] (fitness = 0.999999903999662))
# Ciclo 20, Mejor solucion del ciclo = [-1.0510513e-08 -1.0510513e-08] (fitness = 0.999999957957943))
# Ciclo 25, Mejor solucion del ciclo = [-2.20088927e-11 -2.20088927e-11] (fitness = 0.9999999999119642))
# Ciclo 30, Mejor solucion del ciclo = [-2.02403344e-12 -2.02403344e-12] (fitness = 0.9999999999919038))
# Ciclo 35, Mejor solucion del ciclo = [1.85287397e-14 1.85287397e-14] (fitness = 0.9999999999999258))
# Ciclo 40, Mejor solucion del ciclo = [-1.44442844e-16 -1.44442844e-16] (fitness = 1.0000000000000004))
# Ciclo 45, Mejor solucion del ciclo = [-8.19411202e-17 -8.19411202e-17] (fitness = 1.0000000000000004))
# Mejor solucion encontrada por PSO: [-1.45053291e-16 -1.45053291e-16], fitness = 1.0000000000000004. Tomo 0.031087636947631836 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.03364676 -0.03364676] (fitness = 0.8375310183343307))
# Ciclo 10, Mejor solucion del ciclo = [-0.00076331 -0.00076331] (fitness = 0.9969252267757697))
# Ciclo 15, Mejor solucion del ciclo = [-3.27857445e-05 -3.27857445e-05] (fitness = 0.9998688169874421))
# Ciclo 20, Mejor solucion del ciclo = [-1.80021092e-07 -1.80021092e-07] (fitness = 0.9999992799144255))
# Ciclo 25, Mejor solucion del ciclo = [-4.73216298e-10 -4.73216298e-10] (fitness = 0.9999999981071359))
# Ciclo 30, Mejor solucion del ciclo = [-3.98661353e-10 -3.98661353e-10] (fitness = 0.9999999984053578))
# Ciclo 35, Mejor solucion del ciclo = [-3.95620323e-10 -3.95620323e-10] (fitness = 0.9999999984175187))
# Ciclo 40, Mejor solucion del ciclo = [-3.95576693e-10 -3.95576693e-10] (fitness = 0.9999999984176928))
# Ciclo 45, Mejor solucion del ciclo = [-3.95571639e-10 -3.95571639e-10] (fitness = 0.9999999984177141))
# Mejor solucion encontrada por PSO: [-3.9557164e-10 -3.9557164e-10], fitness = 0.9999999984177141. Tomo 0.022957801818847656 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.0774793 0.0774793] (fitness = 0.6227939261014813))
# Ciclo 10, Mejor solucion del ciclo = [0.00382457 0.00382457] (fitness = 0.9841772429004048))
# Ciclo 15, Mejor solucion del ciclo = [0.0035191 0.0035191] (fitness = 0.9854781719446968))
# Ciclo 20, Mejor solucion del ciclo = [0.00351866 0.00351866] (fitness = 0.9854800461753267))
# Ciclo 25, Mejor solucion del ciclo = [0.00351866 0.00351866] (fitness = 0.9854800463016945))
# Ciclo 30, Mejor solucion del ciclo = [0.00351856 0.00351856] (fitness = 0.9854804415733067))
# Ciclo 35, Mejor solucion del ciclo = [0.00351856 0.00351856] (fitness = 0.9854804416486137))
# Ciclo 40, Mejor solucion del ciclo = [0.00351856 0.00351856] (fitness = 0.9854804416488703))
# Ciclo 45, Mejor solucion del ciclo = [0.00351856 0.00351856] (fitness = 0.9854804416488703))
# Mejor solucion encontrada por PSO: [0.00351856 0.00351856], fitness = 0.9854804416488703. Tomo 0.02039170265197754 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.06637576 0.06637576] (fitness = 0.6724797181397528))
# Ciclo 10, Mejor solucion del ciclo = [-0.00049552 -0.00049552] (fitness = 0.998008825643185))
# Ciclo 15, Mejor solucion del ciclo = [1.17082639e-05 1.17082639e-05] (fitness = 0.9999531618377859))
# Ciclo 20, Mejor solucion del ciclo = [8.70458825e-06 8.70458825e-06] (fitness = 0.9999651788243049))
# Ciclo 25, Mejor solucion del ciclo = [8.21865821e-06 8.21865821e-06] (fitness = 0.9999671228508196))
# Ciclo 30, Mejor solucion del ciclo = [8.21834916e-06 8.21834916e-06] (fitness = 0.999967124087199))
# Ciclo 35, Mejor solucion del ciclo = [8.21834915e-06 8.21834915e-06] (fitness = 0.9999671240872239))
# Ciclo 40, Mejor solucion del ciclo = [8.21834915e-06 8.21834915e-06] (fitness = 0.9999671240872239))
# Ciclo 45, Mejor solucion del ciclo = [8.21834915e-06 8.21834915e-06] (fitness = 0.9999671240872239))
# Mejor solucion encontrada por PSO: [8.21834915e-06 8.21834915e-06], fitness = 0.9999671240872239. Tomo 0.019432783126831055 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.01619214 0.01619214] (fitness = 0.9270560638268822))
# Ciclo 10, Mejor solucion del ciclo = [0.01619069 0.01619069] (fitness = 0.9270632142903024))
# Ciclo 15, Mejor solucion del ciclo = [0.01619068 0.01619068] (fitness = 0.9270632547227667))
# Ciclo 20, Mejor solucion del ciclo = [0.01619068 0.01619068] (fitness = 0.9270632547258426))
# Ciclo 25, Mejor solucion del ciclo = [0.01619068 0.01619068] (fitness = 0.9270632549874623))
# Ciclo 30, Mejor solucion del ciclo = [0.01619068 0.01619068] (fitness = 0.9270632549874623))
# Ciclo 35, Mejor solucion del ciclo = [0.01619068 0.01619068] (fitness = 0.9270632549874623))
# Ciclo 40, Mejor solucion del ciclo = [0.01619068 0.01619068] (fitness = 0.9270632549874623))
# Ciclo 45, Mejor solucion del ciclo = [0.01619068 0.01619068] (fitness = 0.9270632549874623))
# Mejor solucion encontrada por PSO: [0.01619068 0.01619068], fitness = 0.9270632549874623. Tomo 0.020397424697875977 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.00190225 -0.00190225] (fitness = 0.9922586875796002))
# Ciclo 10, Mejor solucion del ciclo = [-2.83547428e-05 -2.83547428e-05] (fitness = 0.9998865510830343))
# Ciclo 15, Mejor solucion del ciclo = [-9.23188389e-08 -9.23188389e-08] (fitness = 0.9999996307243282))
# Ciclo 20, Mejor solucion del ciclo = [-5.09747385e-08 -5.09747385e-08] (fitness = 0.9999997961009497))
# Ciclo 25, Mejor solucion del ciclo = [-5.01528188e-08 -5.01528188e-08] (fitness = 0.9999997993886309))
# Ciclo 30, Mejor solucion del ciclo = [-5.01486948e-08 -5.01486948e-08] (fitness = 0.9999997994051262))
# Ciclo 35, Mejor solucion del ciclo = [-5.01486283e-08 -5.01486283e-08] (fitness = 0.9999997994053926))
# Ciclo 40, Mejor solucion del ciclo = [-5.01486284e-08 -5.01486284e-08] (fitness = 0.9999997994053926))
# Ciclo 45, Mejor solucion del ciclo = [-5.01486284e-08 -5.01486284e-08] (fitness = 0.9999997994053926))
# Mejor solucion encontrada por PSO: [-5.01486283e-08 -5.01486283e-08], fitness = 0.9999997994053926. Tomo 0.02156543731689453 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.07439467 0.07439467] (fitness = 0.6361813348636285))
# Ciclo 10, Mejor solucion del ciclo = [0.03016998 0.03016998] (fitness = 0.855741781395177))
# Ciclo 15, Mejor solucion del ciclo = [0.03015823 0.03015823] (fitness = 0.8558032163968649))
# Ciclo 20, Mejor solucion del ciclo = [0.03015822 0.03015822] (fitness = 0.8558032369565991))
# Ciclo 25, Mejor solucion del ciclo = [0.03015822 0.03015822] (fitness = 0.8558032373295672))
# Ciclo 30, Mejor solucion del ciclo = [0.03015822 0.03015822] (fitness = 0.8558032373304473))
# Ciclo 35, Mejor solucion del ciclo = [0.03015822 0.03015822] (fitness = 0.8558032373306024))
# Ciclo 40, Mejor solucion del ciclo = [0.03015822 0.03015822] (fitness = 0.8558032373306024))
# Ciclo 45, Mejor solucion del ciclo = [0.03015822 0.03015822] (fitness = 0.8558032373306024))
# Mejor solucion encontrada por PSO: [0.03015822 0.03015822], fitness = 0.8558032373306024. Tomo 0.020127058029174805 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.00025818 -0.00025818] (fitness = 0.9989647975088092))
# Ciclo 10, Mejor solucion del ciclo = [-9.66377348e-06 -9.66377348e-06] (fitness = 0.9999613414270575))
# Ciclo 15, Mejor solucion del ciclo = [-6.81479016e-06 -6.81479016e-06] (fitness = 0.9999727391092306))
# Ciclo 20, Mejor solucion del ciclo = [-6.81479007e-06 -6.81479007e-06] (fitness = 0.9999727391095823))
# Ciclo 25, Mejor solucion del ciclo = [-6.8144357e-06 -6.8144357e-06] (fitness = 0.9999727405272612))
# Ciclo 30, Mejor solucion del ciclo = [-6.81443567e-06 -6.81443567e-06] (fitness = 0.9999727405273748))
# Ciclo 35, Mejor solucion del ciclo = [-6.81443567e-06 -6.81443567e-06] (fitness = 0.9999727405273819))
# Ciclo 40, Mejor solucion del ciclo = [-6.81443567e-06 -6.81443567e-06] (fitness = 0.9999727405273819))
# Ciclo 45, Mejor solucion del ciclo = [-6.81443567e-06 -6.81443567e-06] (fitness = 0.9999727405273819))
# Mejor solucion encontrada por PSO: [-6.81443567e-06 -6.81443567e-06], fitness = 0.9999727405273819. Tomo 0.019967317581176758 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.0244378 0.0244378] (fitness = 0.885499197805756))
# Ciclo 10, Mejor solucion del ciclo = [-0.00629425 -0.00629425] (fitness = 0.9734389289598182))
# Ciclo 15, Mejor solucion del ciclo = [5.74015181e-05 5.74015181e-05] (fitness = 0.9997702712375263))
# Ciclo 20, Mejor solucion del ciclo = [1.63240023e-05 1.63240023e-05] (fitness = 0.9999346940644553))
# Ciclo 25, Mejor solucion del ciclo = [1.62624961e-05 1.62624961e-05] (fitness = 0.9999349401637676))
# Ciclo 30, Mejor solucion del ciclo = [1.62607907e-05 1.62607907e-05] (fitness = 0.9999349469875067))
# Ciclo 35, Mejor solucion del ciclo = [1.62607871e-05 1.62607871e-05] (fitness = 0.9999349470020878))
# Ciclo 40, Mejor solucion del ciclo = [1.62607869e-05 1.62607869e-05] (fitness = 0.9999349470026708))
# Ciclo 45, Mejor solucion del ciclo = [1.62607869e-05 1.62607869e-05] (fitness = 0.9999349470026708))
# Mejor solucion encontrada por PSO: [1.62607869e-05 1.62607869e-05], fitness = 0.9999349470026708. Tomo 0.024096250534057617 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.01138995 -0.01138995] (fitness = 0.9501575771342845))
# Ciclo 10, Mejor solucion del ciclo = [-3.32434098e-05 -3.32434098e-05] (fitness = 0.9998669852005948))
# Ciclo 15, Mejor solucion del ciclo = [-9.66605599e-07 -9.66605599e-07] (fitness = 0.9999961335427938))
# Ciclo 20, Mejor solucion del ciclo = [1.65932421e-07 1.65932421e-07] (fitness = 0.9999993362692918))
# Ciclo 25, Mejor solucion del ciclo = [-2.46493027e-10 -2.46493027e-10] (fitness = 0.99999999901403))
# Ciclo 30, Mejor solucion del ciclo = [-2.36063096e-10 -2.36063096e-10] (fitness = 0.9999999990557495))
# Ciclo 35, Mejor solucion del ciclo = [2.12514509e-10 2.12514509e-10] (fitness = 0.9999999991499426))
# Ciclo 40, Mejor solucion del ciclo = [-5.4801037e-13 -5.4801037e-13] (fitness = 0.9999999999978084))
# Ciclo 45, Mejor solucion del ciclo = [2.56916924e-14 2.56916924e-14] (fitness = 0.9999999999998974))
# Mejor solucion encontrada por PSO: [8.10651298e-15 8.10651298e-15], fitness = 0.9999999999999685. Tomo 0.02516484260559082 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.00048478 -0.00048478] (fitness = 0.9980521625891963))
# Ciclo 10, Mejor solucion del ciclo = [1.14901938e-05 1.14901938e-05] (fitness = 0.9999540343066824))
# Ciclo 15, Mejor solucion del ciclo = [1.20817871e-08 1.20817871e-08] (fitness = 0.9999999516728467))
# Ciclo 20, Mejor solucion del ciclo = [6.72138482e-11 6.72138482e-11] (fitness = 0.9999999997311453))
# Ciclo 25, Mejor solucion del ciclo = [2.5556069e-11 2.5556069e-11] (fitness = 0.9999999998977747))
# Ciclo 30, Mejor solucion del ciclo = [2.5479056e-11 2.5479056e-11] (fitness = 0.9999999998980837))
# Ciclo 35, Mejor solucion del ciclo = [-2.31036139e-12 -2.31036139e-12] (fitness = 0.9999999999907598))
# Ciclo 40, Mejor solucion del ciclo = [-2.2284569e-15 -2.2284569e-15] (fitness = 0.9999999999999933))
# Ciclo 45, Mejor solucion del ciclo = [-1.06190935e-15 -1.06190935e-15] (fitness = 0.9999999999999969))
# Mejor solucion encontrada por PSO: [-9.55760701e-16 -9.55760701e-16], fitness = 0.9999999999999969. Tomo 0.022472381591796875 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.07044131 0.07044131] (fitness = 0.6538119036202197))
# Ciclo 10, Mejor solucion del ciclo = [0.00071403 0.00071403] (fitness = 0.9971250308927023))
# Ciclo 15, Mejor solucion del ciclo = [0.00010188 0.00010188] (fitness = 0.9995921056309343))
# Ciclo 20, Mejor solucion del ciclo = [0.00010151 0.00010151] (fitness = 0.9995935694615175))
# Ciclo 25, Mejor solucion del ciclo = [0.00010151 0.00010151] (fitness = 0.999593570102586))
# Ciclo 30, Mejor solucion del ciclo = [0.00010151 0.00010151] (fitness = 0.999593570102586))
# Ciclo 35, Mejor solucion del ciclo = [0.00010151 0.00010151] (fitness = 0.999593570102586))
# Ciclo 40, Mejor solucion del ciclo = [0.00010151 0.00010151] (fitness = 0.999593570102586))
# Ciclo 45, Mejor solucion del ciclo = [0.00010151 0.00010151] (fitness = 0.999593570102586))
# Mejor solucion encontrada por PSO: [0.00010151 0.00010151], fitness = 0.999593570102586. Tomo 0.020456314086914062 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.08067114 0.08067114] (fitness = 0.6092884725350801))
# Ciclo 10, Mejor solucion del ciclo = [-0.00353131 -0.00353131] (fitness = 0.9854262654404785))
# Ciclo 15, Mejor solucion del ciclo = [-0.00313795 -0.00313795] (fitness = 0.9870926467403762))
# Ciclo 20, Mejor solucion del ciclo = [-0.00313788 -0.00313788] (fitness = 0.9870929163221643))
# Ciclo 25, Mejor solucion del ciclo = [-0.00313788 -0.00313788] (fitness = 0.9870929572690956))
# Ciclo 30, Mejor solucion del ciclo = [-0.00313788 -0.00313788] (fitness = 0.9870929572690995))
# Ciclo 35, Mejor solucion del ciclo = [-0.00313788 -0.00313788] (fitness = 0.9870929572707174))
# ...
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.00052444 0.00052444] (fitness = 0.997892062379587))
# Ciclo 10, Mejor solucion del ciclo = [7.94356863e-05 7.94356863e-05] (fitness = 0.9996820223452952))
# Ciclo 15, Mejor solucion del ciclo = [6.73100077e-05 6.73100077e-05] (fitness = 0.9997305912828248))
# Ciclo 20, Mejor solucion del ciclo = [6.73095034e-05 6.73095034e-05] (fitness = 0.9997305933025171))
# Ciclo 25, Mejor solucion del ciclo = [6.73082101e-05 6.73082101e-05] (fitness = 0.9997305984821769))
# Ciclo 30, Mejor solucion del ciclo = [6.73082101e-05 6.73082101e-05] (fitness = 0.9997305984821947))
# Ciclo 35, Mejor solucion del ciclo = [6.73082101e-05 6.73082101e-05] (fitness = 0.9997305984821947))
# Ciclo 40, Mejor solucion del ciclo = [6.73082101e-05 6.73082101e-05] (fitness = 0.9997305984821947))
# Ciclo 45, Mejor solucion del ciclo = [6.73082101e-05 6.73082101e-05] (fitness = 0.9997305984822018))
# Mejor solucion encontrada por PSO: [6.73082101e-05 6.73082101e-05], fitness = 0.9997305984822159. Tomo 0.021576642990112305 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.00888828 0.00888828] (fitness = 0.9617640102126627))
# Ciclo 10, Mejor solucion del ciclo = [-0.00050043 -0.00050043] (fitness = 0.9979889852026292))
# Ciclo 15, Mejor solucion del ciclo = [-3.50530806e-06 -3.50530806e-06] (fitness = 0.9999859783099845))
# Ciclo 20, Mejor solucion del ciclo = [-2.54427016e-06 -2.54427016e-06] (fitness = 0.9999898226781969))
# Ciclo 25, Mejor solucion del ciclo = [-2.5038691e-06 -2.5038691e-06] (fitness = 0.9999899842900112))
# Ciclo 30, Mejor solucion del ciclo = [-2.5038691e-06 -2.5038691e-06] (fitness = 0.9999899842900183))
# Ciclo 35, Mejor solucion del ciclo = [-2.5038691e-06 -2.5038691e-06] (fitness = 0.9999899842900183))
# Ciclo 40, Mejor solucion del ciclo = [-2.5038691e-06 -2.5038691e-06] (fitness = 0.9999899842900254))
# Ciclo 45, Mejor solucion del ciclo = [-2.5038691e-06 -2.5038691e-06] (fitness = 0.9999899842900325))
# Mejor solucion encontrada por PSO: [-2.5038691e-06 -2.5038691e-06], fitness = 0.9999899842900325. Tomo 0.01971435546875 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [-0.21581103 -0.21581103] (fitness = 0.3007003610041597))
# Ciclo 5, Mejor solucion del ciclo = [-0.0020423 -0.0020423] (fitness = 0.9916785210068804))
# Ciclo 10, Mejor solucion del ciclo = [-6.47641865e-05 -6.47641865e-05] (fitness = 0.999740787082571))
# Ciclo 15, Mejor solucion del ciclo = [-6.4551882e-05 -6.4551882e-05] (fitness = 0.999741637322515))
# Ciclo 20, Mejor solucion del ciclo = [-6.4551407e-05 -6.4551407e-05] (fitness = 0.999741639225048))
# Ciclo 25, Mejor solucion del ciclo = [-6.45442805e-05 -6.45442805e-05] (fitness = 0.999741667765302))
# Ciclo 30, Mejor solucion del ciclo = [-6.45442594e-05 -6.45442594e-05] (fitness = 0.9997416678495396))
# Ciclo 35, Mejor solucion del ciclo = [-6.45442594e-05 -6.45442594e-05] (fitness = 0.9997416678495613))
# Ciclo 40, Mejor solucion del ciclo = [-6.45442594e-05 -6.45442594e-05] (fitness = 0.9997416678495613))
# Ciclo 45, Mejor solucion del ciclo = [-6.45442594e-05 -6.45442594e-05] (fitness = 0.9997416678495613))
# Mejor solucion encontrada por PSO: [-6.45442594e-05 -6.45442594e-05], fitness = 0.9997416678495613. Tomo 0.01915884017944336 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.06808468 -0.06808468] (fitness = 0.6645679695985096))
# Ciclo 10, Mejor solucion del ciclo = [-0.00240867 -0.00240867] (fitness = 0.990154260054615))
# Ciclo 15, Mejor solucion del ciclo = [0.00046401 0.00046401] (fitness = 0.998135975912869))
# Ciclo 20, Mejor solucion del ciclo = [-8.31363624e-06 -8.31363624e-06] (fitness = 0.9999667428801857))
# Ciclo 25, Mejor solucion del ciclo = [-7.95604715e-06 -7.95604715e-06] (fitness = 0.9999681734532815))
# Ciclo 30, Mejor solucion del ciclo = [-7.95526153e-06 -7.95526153e-06] (fitness = 0.9999681765962125))
# Ciclo 35, Mejor solucion del ciclo = [-7.9552613e-06 -7.9552613e-06] (fitness = 0.9999681765971296))
# Ciclo 40, Mejor solucion del ciclo = [-7.95526126e-06 -7.95526126e-06] (fitness = 0.9999681765972894))
# Ciclo 45, Mejor solucion del ciclo = [-7.95526126e-06 -7.95526126e-06] (fitness = 0.9999681765972894))
# Mejor solucion encontrada por PSO: [-7.95526126e-06 -7.95526126e-06], fitness = 0.9999681765972894. Tomo 0.02088189125061035 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.08391667 0.08391667] (fitness = 0.5959221898070299))
# Ciclo 10, Mejor solucion del ciclo = [0.00131213 0.00131213] (fitness = 0.9946881625057529))
# Ciclo 15, Mejor solucion del ciclo = [3.59861868e-05 3.59861868e-05] (fitness = 0.9998560070220641))
# Ciclo 20, Mejor solucion del ciclo = [-1.06761762e-06 -1.06761762e-06] (fitness = 0.9999957294870363))
# Ciclo 25, Mejor solucion del ciclo = [-1.0477396e-06 -1.0477396e-06] (fitness = 0.9999958090006963))
# Ciclo 30, Mejor solucion del ciclo = [-1.02840179e-06 -1.02840179e-06] (fitness = 0.9999958863534536))
# Ciclo 35, Mejor solucion del ciclo = [-1.02812487e-06 -1.02812487e-06] (fitness = 0.9999958874611402))
# Ciclo 40, Mejor solucion del ciclo = [-1.02812486e-06 -1.02812486e-06] (fitness = 0.9999958874611793))
# Ciclo 45, Mejor solucion del ciclo = [-1.02812486e-06 -1.02812486e-06] (fitness = 0.9999958874611793))
# Mejor solucion encontrada por PSO: [-1.02812486e-06 -1.02812486e-06], fitness = 0.9999958874611793. Tomo 0.02377176284790039 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.00415161 0.00415161] (fitness = 0.9827776405693115))
# Ciclo 10, Mejor solucion del ciclo = [-1.73400588e-05 -1.73400588e-05] (fitness = 0.9999306285646111))
# Ciclo 15, Mejor solucion del ciclo = [-2.5319323e-06 -2.5319323e-06] (fitness = 0.999989872031951))
# Ciclo 20, Mejor solucion del ciclo = [-4.53741484e-07 -4.53741484e-07] (fitness = 0.999998185026392))
# Ciclo 25, Mejor solucion del ciclo = [-2.61356751e-07 -2.61356751e-07] (fitness = 0.9999989545704513))
# Ciclo 30, Mejor solucion del ciclo = [-2.61356021e-07 -2.61356021e-07] (fitness = 0.9999989545733716))
# Ciclo 35, Mejor solucion del ciclo = [-2.61355979e-07 -2.61355979e-07] (fitness = 0.9999989545735422))
# Ciclo 40, Mejor solucion del ciclo = [-2.61355936e-07 -2.61355936e-07] (fitness = 0.9999989545737091))
# Ciclo 45, Mejor solucion del ciclo = [-2.61355936e-07 -2.61355936e-07] (fitness = 0.9999989545737127))
# Mejor solucion encontrada por PSO: [-2.61355936e-07 -2.61355936e-07], fitness = 0.9999989545737127. Tomo 0.020688295364379883 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.01369937 0.01369937] (fitness = 0.9391721193693027))
# Ciclo 10, Mejor solucion del ciclo = [-0.00015966 -0.00015966] (fitness = 0.9993604301005586))
# Ciclo 15, Mejor solucion del ciclo = [-0.00014238 -0.00014238] (fitness = 0.9994297250957727))
# Ciclo 20, Mejor solucion del ciclo = [-0.00014203 -0.00014203] (fitness = 0.9994311178142361))
# Ciclo 25, Mejor solucion del ciclo = [-0.00014203 -0.00014203] (fitness = 0.9994311195372879))
# Ciclo 30, Mejor solucion del ciclo = [-0.00014203 -0.00014203] (fitness = 0.9994311195402156))
# Ciclo 35, Mejor solucion del ciclo = [-0.00014203 -0.00014203] (fitness = 0.9994311195404223))
# Ciclo 40, Mejor solucion del ciclo = [-0.00014203 -0.00014203] (fitness = 0.9994311195404223))
# Ciclo 45, Mejor solucion del ciclo = [-0.00014203 -0.00014203] (fitness = 0.9994311195404223))
# Mejor solucion encontrada por PSO: [-0.00014203 -0.00014203], fitness = 0.9994311195404223. Tomo 0.019983768463134766 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.00102719 -0.00102719] (fitness = 0.9958523228620991))
# Ciclo 10, Mejor solucion del ciclo = [0.00049772 0.00049772] (fitness = 0.9979999366087946))
# Ciclo 15, Mejor solucion del ciclo = [1.31108221e-07 1.31108221e-07] (fitness = 0.999999475566476))
# Ciclo 20, Mejor solucion del ciclo = [1.20498271e-07 1.20498271e-07] (fitness = 0.9999995180063738))
# Ciclo 25, Mejor solucion del ciclo = [4.96588029e-08 4.96588029e-08] (fitness = 0.9999998013646983))
# Ciclo 30, Mejor solucion del ciclo = [4.96131649e-08 4.96131649e-08] (fitness = 0.9999998015472474))
# Ciclo 35, Mejor solucion del ciclo = [4.00042426e-09 4.00042426e-09] (fitness = 0.9999999839983003))
# Ciclo 40, Mejor solucion del ciclo = [3.98939355e-09 3.98939355e-09] (fitness = 0.999999984042425))
# Ciclo 45, Mejor solucion del ciclo = [3.98933162e-09 3.98933162e-09] (fitness = 0.9999999840426737))
# Mejor solucion encontrada por PSO: [3.98933161e-09 3.98933161e-09], fitness = 0.9999999840426737. Tomo 0.021721839904785156 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.00074557 -0.00074557] (fitness = 0.996997149286439))
# Ciclo 10, Mejor solucion del ciclo = [-7.64429376e-05 -7.64429376e-05] (fitness = 0.9996940107008382))
# Ciclo 15, Mejor solucion del ciclo = [-7.46968114e-05 -7.46968114e-05] (fitness = 0.9997010050269923))
# Ciclo 20, Mejor solucion del ciclo = [-7.46942394e-05 -7.46942394e-05] (fitness = 0.9997010153293227))
# Ciclo 25, Mejor solucion del ciclo = [-7.46936053e-05 -7.46936053e-05] (fitness = 0.9997010178693887))
# Ciclo 30, Mejor solucion del ciclo = [-7.46936053e-05 -7.46936053e-05] (fitness = 0.9997010178695631))
# Ciclo 35, Mejor solucion del ciclo = [-7.46936053e-05 -7.46936053e-05] (fitness = 0.9997010178695631))
# Ciclo 40, Mejor solucion del ciclo = [-7.46936053e-05 -7.46936053e-05] (fitness = 0.9997010178695631))
# Ciclo 45, Mejor solucion del ciclo = [-7.46936053e-05 -7.46936053e-05] (fitness = 0.9997010178695631))
# Mejor solucion encontrada por PSO: [-7.46936053e-05 -7.46936053e-05], fitness = 0.9997010178695631. Tomo 0.026132822036743164 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.00198751 0.00198751] (fitness = 0.9919056462926732))
# Ciclo 10, Mejor solucion del ciclo = [0.00070443 0.00070443] (fitness = 0.9971639330697868))
# Ciclo 15, Mejor solucion del ciclo = [0.00064599 0.00064599] (fitness = 0.9974005844985129))
# Ciclo 20, Mejor solucion del ciclo = [0.00064599 0.00064599] (fitness = 0.9974005888638712))
# Ciclo 25, Mejor solucion del ciclo = [0.00064599 0.00064599] (fitness = 0.9974005920362229))
# Ciclo 30, Mejor solucion del ciclo = [0.00064599 0.00064599] (fitness = 0.9974005920362838))
# Ciclo 35, Mejor solucion del ciclo = [0.00064599 0.00064599] (fitness = 0.9974005920362838))
# Ciclo 40, Mejor solucion del ciclo = [0.00064599 0.00064599] (fitness = 0.9974005920362908))
# Ciclo 45, Mejor solucion del ciclo = [0.00064599 0.00064599] (fitness = 0.9974005920363086))
# Mejor solucion encontrada por PSO: [0.00064599 0.00064599], fitness = 0.9974005920363086. Tomo 0.02335977554321289 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.02780692 0.02780692] (fitness = 0.8680639822705744))
# Ciclo 10, Mejor solucion del ciclo = [-0.00024911 -0.00024911] (fitness = 0.999001258242885))
# Ciclo 15, Mejor solucion del ciclo = [-7.65176863e-05 -7.65176863e-05] (fitness = 0.9996937112805273))
# Ciclo 20, Mejor solucion del ciclo = [-4.08420107e-05 -4.08420107e-05] (fitness = 0.9998365698351105))
# Ciclo 25, Mejor solucion del ciclo = [-4.08339132e-05 -4.08339132e-05] (fitness = 0.9998366022496152))
# Ciclo 30, Mejor solucion del ciclo = [-4.08339132e-05 -4.08339132e-05] (fitness = 0.9998366022496152))
# Ciclo 35, Mejor solucion del ciclo = [-4.08339132e-05 -4.08339132e-05] (fitness = 0.9998366022496152))
# Ciclo 40, Mejor solucion del ciclo = [-4.08339132e-05 -4.08339132e-05] (fitness = 0.9998366022496152))
# Ciclo 45, Mejor solucion del ciclo = [-4.08339132e-05 -4.08339132e-05] (fitness = 0.9998366022496223))
# Mejor solucion encontrada por PSO: [-4.08339132e-05 -4.08339132e-05], fitness = 0.9998366022496223. Tomo 0.020846128463745117 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [-0.00269737 -0.00269737] (fitness = 0.9889466085208434))
# Ciclo 10, Mejor solucion del ciclo = [0.00141533 0.00141533] (fitness = 0.9942650660617232))
# Ciclo 15, Mejor solucion del ciclo = [0.00025538 0.00025538] (fitness = 0.9989760599755798))
# Ciclo 20, Mejor solucion del ciclo = [0.00022388 0.00022388] (fitness = 0.9991026100248654))
# Ciclo 25, Mejor solucion del ciclo = [0.00022388 0.00022388] (fitness = 0.9991026106951073))
# Ciclo 30, Mejor solucion del ciclo = [0.00022388 0.00022388] (fitness = 0.9991026106971371))
# Ciclo 35, Mejor solucion del ciclo = [0.00022388 0.00022388] (fitness = 0.9991026106971407))
# Ciclo 40, Mejor solucion del ciclo = [0.00022388 0.00022388] (fitness = 0.9991026106983114))
# Ciclo 45, Mejor solucion del ciclo = [0.00022388 0.00022388] (fitness = 0.9991026106983114))
# Mejor solucion encontrada por PSO: [0.00022388 0.00022388], fitness = 0.9991026106983114. Tomo 0.02271580696105957 seg
# Iniciando optimizacion con Algoritmo PSO
# Mejor solucion inicial = [0.08396422 0.08396422], fitness = 0.5957291020449789
# Ciclo 0, Mejor solucion del ciclo = [0.21641209 0.21641209] (fitness = 0.30008112958026234))
# Ciclo 5, Mejor solucion del ciclo = [0.0281495 0.0281495] (fitness = 0.8662815524637772))
# Ciclo 10, Mejor solucion del ciclo = [0.01387455 0.01387455] (fitness = 0.9383290561310577))
# Ciclo 15, Mejor solucion del ciclo = [0.01387243 0.01387243] (fitness = 0.938339241669337))
# Ciclo 20, Mejor solucion del ciclo = [0.01387243 0.01387243] (fitness = 0.9383392620642107))
# Ciclo 25, Mejor solucion del ciclo = [0.01387243 0.01387243] (fitness = 0.938339262402131))
# Ciclo 30, Mejor solucion del ciclo = [0.01387243 0.01387243] (fitness = 0.9383392627304261))
# Ciclo 35, Mejor solucion del ciclo = [0.01387243 0.01387243] (fitness = 0.9383392627304856))
# Ciclo 40, Mejor solucion del ciclo = [0.01387243 0.01387243] (fitness = 0.9383392627304856))
# Ciclo 45, Mejor solucion del ciclo = [0.01387243 0.01387243] (fitness = 0.9383392627304856))
# Mejor solucion encontrada por PSO: [0.01387243 0.01387243], fitness = 0.9383392627304856. Tomo 0.01945805549621582 seg

# %%
for index, partial_total in enumerate(total_pso, start = 1):
  print('Combinación ', index)
  partial = np.array(partial_total)
  print('Media: ', partial.mean())
  print('Desviación estándar: ', partial.std())
# Out:
# Combinación  1
# Media:  0.9927140847747516
# Desviación estándar:  0.013428565908251382
# Combinación  2
# Media:  0.9535535464323488
# Desviación estándar:  0.07449830306063204
# Combinación  3
# Media:  0.9214877267649019
# Desviación estándar:  0.12172497818051518
# Combinación  4
# Media:  0.9769427630714018
# Desviación estándar:  0.04578523384526633
# Combinación  5
# Media:  0.9889025326752732
# Desviación estándar:  0.015292390796880797
# Combinación  6
# Media:  0.9783763838034784
# Desviación estándar:  0.04381711378466797
# Combinación  7
# Media:  0.9967626135935783
# Desviación estándar:  0.0036807557777817834
# Combinación  8
# Media:  0.94594258321964
# Desviación estándar:  0.0991474986664221
# Combinación  9
# Media:  0.936254562881596
# Desviación estándar:  0.11181074530497807
# Combinación  10
# Media:  0.9932152528407526
# Desviación estándar:  0.008358176442367651
# Combinación  11
# Media:  0.9748622289041698
# Desviación estándar:  0.0634051268017103
# Combinación  12
# Media:  0.9622463726800181
# Desviación estándar:  0.05913745635230933
# Combinación  13
# Media:  0.9853135824971094
# Desviación estándar:  0.03581310829426869
# Combinación  14
# Media:  0.9439245974143337
# Desviación estándar:  0.0838710931515634
# Combinación  15
# Media:  0.9546779910442014
# Desviación estándar:  0.07187512677140723
# Combinación  16
# Media:  0.9731923757564976
# Desviación estándar:  0.048966803360051055
# Combinación  17
# Media:  0.9770960384044329
# Desviación estándar:  0.04319250735226686
# Combinación  18
# Media:  0.9171311952779311
# Desviación estándar:  0.13856596174649513
# Combinación  19
# Media:  0.9893433136858929
# Desviación estándar:  0.019632078029507234
# Combinación  20
# Media:  0.9834661582249297
# Desviación estándar:  0.02274725732237667
# Combinación  21
# Media:  0.9844203220156074
# Desviación estándar:  0.04085393606752467
# Combinación  22
# Media:  0.9742141433205724
# Desviación estándar:  0.06915407052742696
# Combinación  23
# Media:  0.9988148390473738
# Desviación estándar:  0.0020734786826434983
# Combinación  24
# Media:  0.9673578746393192
# Desviación estándar:  0.06562739020008374
# Combinación  25
# Media:  0.9628378668710506
# Desviación estándar:  0.09823761589942344
# Combinación  26
# Media:  0.981534708236549
# Desviación estándar:  0.02868832668132275
# Combinación  27
# Media:  0.9933774207799569
# Desviación estándar:  0.018361546611150806

# %% [markdown]
# * El mejor es w = 1, phi1 = 2, phi2 = 2, que es la combinación 23, fitness = 0.9988148390473738.
# * En caso de aprendizaje cognitivo y aprendizaje social va mejor cuando hay un equilibrio de exploración y explotación, mientras que la fuerza inercial influye menos, se ha conseguido medias muy cercanas al óptimo en los otros w.
# * Los resultados en ABC son superiores a PSO mientras que los parámetros de ABC indiquen que es más explotativo.
